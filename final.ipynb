# %%
import tensorflow as tf
from tagger import Config, Tagger, calculate_confusion, print_confusion

# %% [markdown]
# #Validation against test set
#
# All three models manifest similar performance. The last model was choosen for final accuracy estimation.
#
# The model is a 3-layered neural network feed with 3-word windows of (preceding word, tagged word, next word) and predicted the tag of center word.

# %%
config = Config()
print config
with tf.Graph().as_default():
    with tf.Session() as session:
        model = Tagger(config)
        init = tf.global_variables_initializer()
        session.run(init)
        saver = tf.train.Saver()
        # Restore previously trained weights
        saver.restore(session, './final_weights/tagger.weights')
        _, predictions = model.predict(session, 
                                       model.X_test, 
                                       model.y_test,
                                       verbose=False
                                       )
        total_correct_examples = 0
        total_processed_examples = len(predictions)
        failed_cases = []
        for i, (y_hat, y) in enumerate(
                zip(predictions, model.y_test)):
            total_correct_examples += 1 if y == y_hat else 0
            if y != y_hat:
                failed_cases.append((i, y_hat, y))
        print 'Test accuracy is', total_correct_examples / float(
            total_processed_examples)
# Out:
# Model hyperparameters:
# window_size: 3
# embed_size: 50
# dropout: 0.9
# batch_size: 64
# l2: 0.003
# max_epochs: 30
# lr: 0.001
# hidden_size: 200
# early_stopping: 2
# 85565 sentences loaded
# 1386544 3-word windows loaded
# Shape of X is (1386544, 3)
# Shape of y is (1386544,)
# Test accuracy is 0.929198370055

# %%
confusion = calculate_confusion(
    predictions, model.y_test, model.tagset_size)
print_confusion(confusion, model.num_to_tag)
# Out:
# Confusion matrix (precission and recall for each tag)
# Tag: pant - P nan / R 0.0000
# Tag: adjp - P 0.9861 / R 0.7802
# Tag: interp - P 0.9997 / R 0.9998
# Tag: num - P 0.9578 / R 0.8257
# Tag: interj - P 1.0000 / R 0.5329
# Tag: adja - P 1.0000 / R 0.1639
# Tag: ppron3 - P 0.9892 / R 0.9922
# Tag: </s> - P 1.0000 / R 1.0000
# Tag: inf - P 0.9345 / R 0.8266
# Tag: adv - P 0.9422 / R 0.8885
# Tag: winien - P 0.9756 / R 0.9524
# Tag: pred - P 0.8864 / R 0.7158
# Tag: subst - P 0.8608 / R 0.9663
# Tag: ppas - P 0.7342 / R 0.4514
# Tag: siebie - P 1.0000 / R 0.9956
# Tag: fin - P 0.8233 / R 0.8875
# Tag: prep - P 0.9878 / R 0.9929
# Tag: conj - P 0.9420 / R 0.9440
# Tag: ger - P 0.7738 / R 0.5454
# Tag: imps - P 1.0000 / R 0.3780
# Tag: pcon - P 0.9832 / R 0.4179
# Tag: comp - P 0.9800 / R 0.9662
# Tag: xxx - P nan / R 0.0000
# Tag: burk - P nan / R 0.0000
# Tag: aglt - P 0.9850 / R 1.0000
# Tag: adjc - P nan / R 0.0000
# Tag: qub - P 0.9562 / R 0.9241
# Tag: bedzie - P 1.0000 / R 1.0000
# Tag: pact - P 0.8653 / R 0.3064
# Tag: praet - P 0.9262 / R 0.7935
# Tag: impt - P 1.0000 / R 0.3778
# Tag: numcol - P nan / R 0.0000
# Tag: adj - P 0.8786 / R 0.8218
# Tag: ppron12 - P 0.9611 / R 0.9912
# Tag: <s> - P 1.0000 / R 1.0000
# Tag: depr - P nan / R 0.0000
# Tag: brev - P 0.9768 / R 0.9006
# tagger.py:277: RuntimeWarning: invalid value encountered in divide
#   prec = confusion[i, i] / float(total_guessed_tags[i])

# %% [markdown]
# ## Examples of mistagged words
#
# The first row is a three word window with center word's tag being predicted. The second row is predicted tag and true tag.
#
# `UUUNKKK` represents unknown word (words with fewer than 5 occurences are dismissed from the first word2vec layer). `<s>` and `</s>` are special tokens marking the beginning and ending of a sentence.

# %%
unks = 0
for i, y_hat, y in failed_cases:
    problematic_word = model.num_to_word[model.X_dev[i][1]]
    if problematic_word == 'UUUNKKK':
        unks += 1
        continue
    print ' '.join([model.num_to_word[model.X_dev[i][j]] 
           for j in range(0, 3)])
    print model.num_to_tag[y_hat], model.num_to_tag[y]
print     
print '{:.2f}% of mistagged words were marked as unknown to the model ' \
      '(i.e. occurred fewer than 5 times in the corpus). The other' \
      ' mistagged words are displayed above.'.format(
    unks/float(len(failed_cases))*100)
# Out:
# całkiem sporo .
# fin adj
# UUUNKKK lęku .
# subst qub
# los ; wierzysz
# subst pact
# tego za jednym
# fin praet
# . </s> <s>
# adj adja
# też wszystkie duże
# subst praet
# o zbyt UUUNKKK
# fin praet
# </s> <s> UUUNKKK
# subst ger
# . </s> <s>
# subst adv
# zarazem , żadnych
# subst praet
# proc . tego
# subst adj
# wyjściu na prostą
# subst ppas
# powiedział , że
# subst adj
# i z kim
# subst adj
# " , który
# adj ppas
# nazywam tak ,
# adj ppas
# bądź co bądź
# ger subst
# , jej adwokat
# prep conj
# ma sensu tworzenia
# subst qub
# </s> <s> to
# subst inf
# ) , tworzenia
# adj ppas
# się na modlitwy
# subst adj
# UUUNKKK do tej
# adv conj
# UUUNKKK był UUUNKKK
# adj ppas
# wypadków . </s>
# subst praet
# – nie </s>
# subst adj
# . </s> <s>
# num adv
# , w której
# subst ppas
# <s> To UUUNKKK
# fin ger
# dziś widzę wyraz
# subst pred
# tygodniu po UUUNKKK
# fin praet
# zginęły w hitlerowskiej
# praet fin
# . </s> <s>
# subst adj
# nie ona była
# subst adj
# widoczne okoliczności tej
# adj fin
# , czy chodzi
# subst ger
# niedzielę . </s>
# adj pact
# potrawy . </s>
# fin praet
# Wiele godzin czekał
# subst ppas
# drugiej strony ,
# fin impt
# warszawskiego biura UUUNKKK
# fin adj
# . jednak to
# qub conj
# Szef klubu partii
# adj fin
# mój apel zgłosiło
# subst fin
# UUUNKKK AM UUUNKKK
# praet fin
# UUUNKKK </s> <s>
# fin ppas
# jednej sekundy łuku
# conj adv
# przyniesie wypłatę a
# praet ppas
# w imieniu Agencji
# conj adj
# A co innego
# subst ger
# </s> <s> –
# subst praet
# że nasi chłopcy
# fin praet
# <s> Trzeba wybrać
# subst adj
# ( województwo UUUNKKK
# adv qub
# . </s> <s>
# adj ger
# <s> - Owszem
# subst ppas
# potwierdziły : tego
# fin praet
# W południe UUUNKKK
# qub conj
# UUUNKKK . </s>
# subst adj
# gdyż nie UUUNKKK
# subst adj
# to tym UUUNKKK
# adj ppas
# . </s> <s>
# subst adv
# UUUNKKK . </s>
# subst adj
# <s> – UUUNKKK
# prep subst
# - ostrzegał UUUNKKK
# subst qub
# toru lotu pocisku
# adj praet
# architektura m.in .
# adj adv
# UUUNKKK ! </s>
# fin praet
# <s> Dlatego UUUNKKK
# subst ppas
# i zaczęli śmy
# fin pact
# , która może
# inf subst
# Sejmowi sprawozdania ,
# adj praet
# chciał em się
# subst depr
# <s> - Wiem
# subst conj
# czasów I wojny
# subst adv
# UUUNKKK ze zbioru
# adj subst
# nie myślał ,
# subst fin
# przez lekarzy i
# brev subst
# ? </s> <s>
# ger adj
# być one znane
# subst num
# UUUNKKK : </s>
# subst ppron12
# . </s> <s>
# brev subst
# poprzednich książek ?
# subst praet
# . </s> <s>
# subst fin
# bez polityki .
# fin ger
# poruszania się po
# subst adj
# Instytutu - powiedział
# qub pred
# <s> " UUUNKKK
# fin praet
# </s> <s> Wojewoda
# subst pcon
# można określić ,
# subst pred
# “ Panie profesorze
# fin ppas
# UUUNKKK koszuli z
# subst adj
# UUUNKKK muszę wyjaśnić
# subst ger
# rozporządzeniu , o
# subst pact
# - krótszy .
# adv qub
# <s> Prokuratura nie
# ppas praet
# poczucie porażki ?
# subst pred
# stali też na
# ger adj
# </s> <s> Zarząd
# inf fin
# czy po prostu
# adv comp
# witamy . </s>
# subst adj
# jak on .
# subst imps
# UUUNKKK podstawy obsługi
# subst adv
# UUUNKKK , że
# fin adv
# z naszego punktu
# ger subst
# , powstanie od
# qub subst
# <s> Narodowe Stowarzyszenie
# qub adv
# mały , że
# adj subst
# <s> Gdy nie
# fin subst
# UUUNKKK </s> <s>
# fin pcon
# pasma gór .
# subst adj
# . </s> <s>
# subst adj
# 5 . UUUNKKK
# subst adj
# No , teraz
# fin praet
# mi bliżej gardła
# subst adj
# nos , będzie
# subst fin
# nigdy nie mówił
# subst praet
# rundzie zasadniczej cztery
# fin praet
# w jakiej sprawie
# inf pcon
# , gdy ktoś
# subst qub
# Minęło 90 UUUNKKK
# fin praet
# UUUNKKK się pod
# subst praet
# panie pośle .
# subst adja
# sklepie 10 tys
# fin praet
# . - zaczął
# fin subst
# także Jarosław R
# subst pact
# , by UUUNKKK
# subst adj
# mieli śmy .
# subst adj
# zadeklarował udostępnienie do
# inf subst
# kiedy to UUUNKKK
# conj adv
# UUUNKKK dziękuję naszemu
# subst impt
# podstawie umowy o
# subst praet
# mieć za rok
# brev interj
# tak straszliwie UUUNKKK
# num adv
# <s> Nie było
# praet subst
# ście na rowery
# subst pred
# dziwne pomysły (
# subst adj
# się w UUUNKKK
# ger adj
# kolei z UUUNKKK
# subst fin
# pod tym względem
# adj fin
# . </s> <s>
# ger subst
# UUUNKKK do złożenia
# subst praet
# , matkę UUUNKKK
# subst adj
# UUUNKKK , które
# fin pcon
# zawołanie to nie
# subst inf
# , roszczenia UUUNKKK
# subst xxx
# w jeszcze wyższym
# prep conj
# – Do wyborów
# fin praet
# UUUNKKK , posiadasz
# qub conj
# Od drogi z
# subst praet
# . Sławomira UUUNKKK
# subst adj
# auto miało UUUNKKK
# subst praet
# już drugi rok
# subst adv
# To pierwsza rzecz
# adv num
# ( choćby w
# subst adj
# bezrobocie wśród młodych
# adj subst
# . </s> <s>
# adj num
# Donald Tusk .
# subst impt
# ? </s> <s>
# subst adj
# zaproszenia . </s>
# subst fin
# by przeznaczyć na
# subst adj
# <s> W UUUNKKK
# subst pred
# . </s> <s>
# subst adj
# XVII i XVIII
# fin subst
# UUUNKKK na temat
# subst fin
# </s> <s> –
# subst adj
# strony ul .
# fin praet
# pracował em .
# subst adj
# </s> <s> To
# conj adv
# UUUNKKK i stworzył
# subst fin
# – To ma
# subst fin
# UUUNKKK szpitale :
# subst adj
# zajmuję no </s>
# subst fin
# nie jest .
# fin praet
# koniec listu .
# adj praet
# zbudowane , raczej
# subst adj
# . </s> <s>
# adj ger
# my też .
# subst adj
# </s> <s> Dopiero
# fin praet
# <s> Na UUUNKKK
# fin inf
# UUUNKKK do UUUNKKK
# fin praet
# Naturalnie , na
# subst adj
# </s> <s> Za
# subst praet
# UUUNKKK </s> <s>
# adv adj
# </s> <s> Lepiej
# conj qub
# <s> – Przynajmniej
# fin pact
# pod kołami samochodów
# subst inf
# czterech tysięcy złotych
# subst adj
# w tym długość
# praet num
# <s> Cóż zrobić
# subst inf
# w ich obrębie
# subst adj
# zadać pytanie ?
# adj pact
# . </s> <s>
# subst pred
# . </s> <s>
# prep interj
# . </s> <s>
# qub conj
# <s> - Z
# fin pcon
# . </s> <s>
# subst conj
# dla bezrobotnych .
# subst adj
# UUUNKKK przez prezydenta
# subst adj
# . </s> <s>
# subst adj
# . w mądrości
# subst adj
# <s> Między innymi
# subst fin
# UUUNKKK grozi posłom
# qub conj
# podwórko , aby
# subst xxx
# UUUNKKK weszły tam
# subst pact
# ciągu 3 -
# fin praet
# już tylko UUUNKKK
# subst praet
# <s> Sądzę ,
# subst fin
# korekty . </s>
# subst praet
# UUUNKKK o dwunastej
# subst ger
# opinii wskazują na
# adj fin
# <s> Albo kandydata
# subst praet
# m.in . UUUNKKK
# subst praet
# było tylko UUUNKKK
# conj qub
# mnie tak ,
# subst adj
# <s> 3 km
# subst praet
# UUUNKKK , czy
# subst adj
# pochyliła mi się
# subst adj
# żywych lub zmarłych
# fin praet
# UUUNKKK duże zainteresowanie
# subst adj
# , BMW ,
# adj num
# r . we
# subst adj
# dłużej niż UUUNKKK
# subst adj
# </s> <s> UUUNKKK
# subst inf
# - Myślała m
# subst praet
# </s> <s> Minister
# adj subst
# przez dwa ,
# subst adj
# UUUNKKK - UUUNKKK
# subst adj
# UUUNKKK . </s>
# subst praet
# rzeczy - wyjaśnił
# subst adj
# wideo , UUUNKKK
# adj ger
# świata po prostu
# subst praet
# w naszym społeczeństwie
# prep subst
# ok . 12
# praet imps
# </s> <s> Saszka
# subst ger
# przebywających na Białorusi
# subst praet
# </s> <s> Za
# fin praet
# chmury w nowe
# subst fin
# </s> <s> STOP
# fin praet
# <s> Daje on
# fin adj
# tylko one są
# subst inf
# <s> Przecież firanki
# subst fin
# , schować ;
# conj qub
# UUUNKKK nowe te
# subst praet
# UUUNKKK i życzliwość
# subst praet
# UUUNKKK bądź UUUNKKK
# subst ger
# Nowym Targu i
# subst adj
# masz </s> <s>
# subst adj
# </s> <s> To
# qub ppron3
# UUUNKKK się ze
# adv num
# drugiego człowieka .
# adj subst
# " domaga się
# subst pact
# . . </s>
# adv qub
# założył nogę na
# subst adj
# stosuje się przepisów
# fin adj
# czy historia .
# subst adj
# bramy ogrodzenia ,
# subst adj
# nie mieli by
# adj subst
# twoich protest UUUNKKK
# subst adv
# UUUNKKK . </s>
# subst inf
# . </s> <s>
# subst xxx
# . </s> <s>
# adj subst
# mam , są
# fin pact
# masz </s> <s>
# subst adj
# są chyba mało
# subst adj
# członków z lat
# subst adj
# mogą liczyć mieszkańcy
# adv qub
# , pytał o
# subst adj
# . </s> <s>
# conj subst
# UUUNKKK dla UUUNKKK
# inf fin
# zapytała mego gościa
# subst ppas
# z dyrektorów UUUNKKK
# adj subst
# ogóle . .
# subst fin
# . </s> <s>
# qub prep
# zawsze jego tajemnicą
# ppas adj
# tak , jak
# subst fin
# mnie po UUUNKKK
# subst praet
# UUUNKKK in one
# subst adj
# </s> <s> Pytam
# subst adj
# UUUNKKK . </s>
# subst inf
# UUUNKKK – odparł
# adj conj
# , zatrzymał em
# fin inf
# dolarów , a
# subst adj
# od poprzedniej Rady
# subst ppas
# , gdy europejskiej
# subst adj
# ten ze zdjęcia
# subst praet
# UUUNKKK gminie trudno
# conj qub
# że wybrali UUUNKKK
# subst adj
# UUUNKKK . </s>
# conj qub
# ze swojego ulubionego
# num adj
# takie wypowiedzi UUUNKKK
# fin adv
# 60 tysięcy żołnierzy
# subst praet
# , a nie
# subst ger
# <s> Obecnie UUUNKKK
# inf adv
# Jarosław Kaczyński ,
# ppas fin
# mieli jednak za
# subst fin
# UUUNKKK Ligi Republikańskiej
# subst inf
# ” ? </s>
# subst praet
# w głowie i
# fin praet
# nerwów , nadziei
# adj num
# którzy cię lubią
# subst adj
# , że mógł
# adj subst
# śpiew w słynnej
# subst adja
# miało mieć charakteru
# subst inf
# UUUNKKK się Państwie
# subst adj
# . </s> <s>
# prep interj
# UUUNKKK by m
# subst adj
# artykuły codziennego użytku
# subst praet
# </s> <s> UUUNKKK
# praet subst
# nic - UUUNKKK
# inf pact
# pół godziny przed
# subst adj
# - A ,
# subst praet
# UUUNKKK będzie zawsze
# subst adj
# mieć pieniądze na
# adv prep
# UUUNKKK , Daniel
# fin pcon
# </s> <s> Sąd
# subst adj
# nowym prawem małżeństwa
# subst adv
# walce z UUUNKKK
# subst brev
# dobrze : niech
# subst praet
# Jest pan uważany
# praet fin
# pracę zawartej na
# subst adja
# że to gwarantuje
# subst ger
# UUUNKKK wczoraj dane
# fin praet
# że był on
# adj ppas
# UUUNKKK wydawca audycji
# fin praet
# . </s> <s>
# subst adj
# wiele łączy .
# adj num
# </s> <s> Tak
# subst ppas
# będę szczęśliwa ,
# subst imps
# UUUNKKK pasuje doskonale
# subst adj
# . </s> <s>
# qub fin
# . </s> <s>
# subst adj
# UUUNKKK . </s>
# adj adjc
# Przemysł spożywczy .
# brev subst
# zobaczyć , jak
# subst fin
# UUUNKKK kontaktu z
# subst num
# , jak było
# praet pcon
# . ustawa UUUNKKK
# subst adj
# . </s> <s>
# adj subst
# UUUNKKK jej UUUNKKK
# subst adj
# <s> I rachunki
# fin pcon
# o których mowa
# num adj
# - poprosiła -
# subst adj
# przecież jeszcze UUUNKKK
# subst ger
# . </s> <s>
# subst adj
# elektryczna była przyczyną
# adj praet
# użytkownik mieszka w
# pred subst
# UUUNKKK , czy
# adj ppas
# jak pan prezes
# subst fin
# UUUNKKK . </s>
# subst adv
# Tymczasem jeden "
# conj qub
# UUUNKKK łzy .
# subst adj
# bardzo mała w
# ger subst
# ? </s> <s>
# qub conj
# czyste sumienie ,
# inf subst
# działać . </s>
# adj praet
# sama , by
# subst praet
# jest uzasadniona ,
# adj ppas
# w Rzymie .
# conj qub
# też , że
# subst adj
# Pamiętaj tylko ,
# subst inf
# UUUNKKK , UUUNKKK
# subst adj
# terenie : -
# adj num
# </s> <s> Działacze
# subst adj
# . </s> <s>
# praet subst
# Jest dobra i
# subst adj
# nimi nie tylko
# qub conj
# nowy polityczny model
# subst ppas
# UUUNKKK do UUUNKKK
# fin praet
# - powiedział nam
# subst inf
# wszystkim musimy postawić
# subst ger
# W finale uczestniczyli
# conj prep
# , w której
# subst fin
# będzie to chyba
# subst fin
# . osób w
# subst praet
# . </s> <s>
# praet fin
# media . </s>
# ppas adj
# informację w rozmowie
# subst adj
# UUUNKKK bardzo dobry
# subst inf
# miasteczku . .
# adj subst
# ( jakoś tego
# subst praet
# nie wiem </s>
# fin pact
# . </s> <s>
# ppas subst
# UUUNKKK , UUUNKKK
# subst adj
# z dzieckiem choćby
# ppas fin
# , nie będą
# subst fin
# nie ma wątpliwości
# adj pact
# żeby rząd odpowiednio
# fin pact
# ? </s> <s>
# subst fin
# ? </s> <s>
# adj adv
# UUUNKKK </s> <s>
# subst impt
# </s> <s> Ks
# subst adj
# szereg ówczesnych wielkich
# subst adj
# em to …
# adj imps
# osoby B brzmi
# subst adv
# rozumu . gdyby
# subst adj
# swoim zaufaniem w
# subst adj
# " I to
# subst ppas
# temat perspektyw UUUNKKK
# subst impt
# <s> A .
# fin praet
# </s> <s> Zapytał
# ger subst
# UUUNKKK . </s>
# subst pred
# , jak i
# fin pcon
# . </s> <s>
# subst qub
# do dotychczasowej UUUNKKK
# subst adj
# <s> Beata UUUNKKK
# ppas inf
# następuje w dniu
# subst inf
# <s> Nie wszyscy
# praet fin
# chyba że jest
# subst adj
# </s> <s> W
# adj subst
# UUUNKKK w teatrze
# subst adj
# ) . </s>
# adj subst
# , firma „
# subst qub
# sprawy , że
# subst adj
# nie ma wystarczająco
# fin subst
# zabronił grać w
# subst adv
# em jednak kilka
# adj ppas
# prawie rok temu
# subst adv
# </s> <s> Na
# subst praet
# UUUNKKK z UUUNKKK
# praet subst
# </s> <s> Prokurator
# subst adj
# </s> <s> Mimo
# subst fin
# głowy za okno
# subst adj
# . </s> <s>
# subst praet
# " Przecież tam
# subst adj
# jednym z wypadków
# praet fin
# rzadkich zjawisk atmosferycznych
# adv num
# . </s> <s>
# subst ger
# UUUNKKK nazwali UUUNKKK
# fin praet
# mogła się z
# adj num
# na stopień nauczyciela
# subst imps
# Po dniach UUUNKKK
# subst ger
# na Słowackiego -
# inf subst
# ście zły przykład
# subst adj
# przeżyła naprawdę ciężki
# subst adj
# że do sklepu
# subst adj
# UUUNKKK , nie
# qub conj
# zamknięcia placówki ,
# subst pcon
# i być może
# adj subst
# UUUNKKK , UUUNKKK
# subst adj
# raz w życiu
# subst adj
# , że biskupi
# subst adj
# wysokich rozgrywkach UUUNKKK
# conj qub
# UUUNKKK akcji na
# adj subst
# naród niemiecki zaczyna
# subst adj
# cudze plecy !
# subst brev
# UUUNKKK . </s>
# adj ger
# spółek notowanych było
# subst adj
# " . </s>
# adj praet
# wiesz co tak
# subst adj
# UUUNKKK o UUUNKKK
# fin adj
# , którym UUUNKKK
# subst impt
# Te dosyć nerwowe
# subst ger
# przepisy Kodeksu postępowania
# subst ppas
# prostu ten popyt
# subst praet
# UUUNKKK L .
# praet subst
# , innym razem
# conj qub
# UUUNKKK , UUUNKKK
# ger adj
# ci tak UUUNKKK
# subst ppas
# dwanaście trzynaście czternaście
# adj subst
# teraz ? </s>
# subst fin
# trzy pytania do
# adj subst
# UUUNKKK reprezentacji UUUNKKK
# conj qub
# kiedykolwiek było lub
# subst num
# , stanowiła by
# subst imps
# piersi uświadomił mu
# subst praet
# , od lat
# adj subst
# . </s> <s>
# subst ger
# powszechnie wiadomo ,
# subst praet
# pracowników z Estonii
# adj ger
# zrozumieć rozmowę .
# fin subst
# - powiedział .
# prep interj
# <s> – ychy
# subst adj
# UUUNKKK . </s>
# adj ppas
# to przecież UUUNKKK
# adj praet
# mieszkaniu odbywała się
# subst adj
# należy rozpocząć niezwłocznie
# subst ppas
# w tym leży
# praet ppas
# <s> K :
# fin subst
# nich w liście
# subst adj
# </s> <s> Ten
# subst adv
# strażnik był </s>
# subst adj
# , czy zmiany
# adv num
# mu się podoba
# adv num
# UUUNKKK . </s>
# subst pred
# miłości . </s>
# fin adv
# . </s> <s>
# subst adv
# UUUNKKK drzew w
# subst adj
# wyznawców od innych
# adj ppas
# zgodę na położenie
# subst inf
# <s> no nie
# ppron12 adj
# , który był
# qub conj
# <s> – no
# subst pred
# Na słoneczne UUUNKKK
# subst praet
# , z którymi
# subst ppas
# jest ? </s>
# fin praet
# szczegółach , dlatego
# fin adj
# parlament nie będzie
# adj num
# UUUNKKK , proste
# fin praet
# innego . </s>
# adj subst
# otrzymała wysokiej jakości
# conj numcol
# gdzie - jak
# subst adj
# Francji , Hiszpanii
# subst pact
# planu zagospodarowania przestrzennego
# subst adj
# Ostatnie miesiące życia
# praet adj
# </s> <s> WDOWA
# subst praet
# . </s> <s>
# subst praet
# </s> <s> Mimo
# adv qub
# prowadzi dzienniki pt
# conj qub
# roku 1996 ukazały
# subst inf
# </s> <s> –
# subst fin
# 2002 r .
# subst adj
# Ale za późno
# adj subst
# . </s> <s>
# subst pred
# <s> To tak
# adj num
# do domu .
# praet pant
# . </s> <s>
# subst adj
# świece . </s>
# subst inf
# Międzynarodowej Unii UUUNKKK
# subst ppas
# Wiele jednak zależy
# num adv
# <s> Na UUUNKKK
# subst xxx
# piśmie , że
# subst adj
# UUUNKKK zachowaniu UUUNKKK
# ppas praet
# mieli śmy UUUNKKK
# adj pact
# <s> fajne miasto
# subst praet
# zajmowali wysokie miejsca
# subst adj
# <s> Harry wówczas
# fin inf
# na nowo pojęcia
# fin subst
# UUUNKKK , dopiero
# subst adj
# , a drugi
# adj praet
# historii miasta .
# subst praet
# to i te
# subst qub
# w Nakle od
# subst adj
# jest czynne trzy
# fin praet
# polityczną , być
# subst pact
# </s> <s> Jak
# subst adj
# rozgrywkach UEFA .
# praet subst
# okno , gdzie
# subst adj
# Nie wszyscy uczestnicy
# qub conj
# UUUNKKK , bo
# subst adj
# UUUNKKK znalazł się
# subst inf
# UUUNKKK , który
# subst fin
# <s> Największe cięcia
# adj fin
# Które towary UUUNKKK
# subst adj
# </s> <s> W
# subst adj
# słyszał em -
# qub conj
# wszyscy : politycy
# subst praet
# o szkolnictwie wyższym
# prep qub
# tam nie być
# qub adv
#  </s> <s>
# subst adj
# zainteresowania Rosji .
# subst adj
# </s> <s> UUUNKKK
# subst adj
# jaki musiał być
# subst ger
# UUUNKKK od czasu
# subst adj
# nie jest wcale
# subst ger
# </s> <s> Wystarczy
# subst ger
# cen leków .
# subst adv
# na swojej pracy
# subst adj
# UUUNKKK za usługi
# fin praet
# </s> <s> –
# subst praet
# </s> <s> No
# qub conj
# . osób (
# subst praet
# wydaniu Gazety .
# ger pact
# z lat siedemdziesiątych
# conj qub
# 60 . ,
# subst pact
# dziurę można UUUNKKK
# subst inf
# czyli właśnie to
# subst comp
# ( a Karina
# adj ppas
# UUUNKKK go to
# subst adj
# ona ponosi winę
# subst adj
# <s> Jeżeli chodzi
# adj subst
# UUUNKKK . </s>
# adj subst
# UUUNKKK od kilku
# subst adj
# i jedno z
# subst adj
# <s> my by
# subst fin
# jak ma zapłacić
# subst ger
# wykonywaniem pracy UUUNKKK
# fin praet
# </s> <s> Sytuacja
# conj impt
# pod uwagę .
# subst ppas
# seksualnego , wchodząc
# adj ger
# do realizacji sprawy
# subst xxx
# którą został UUUNKKK
# subst pact
# naród nie chce
# subst praet
# UUUNKKK do UUUNKKK
# fin praet
# Ty na pewno
# subst praet
# ale po uzyskaniu
# adj ppas
# " Teraz na
# subst adj
# wracał do kraju
# subst adj
# wierszy , UUUNKKK
# conj brev
# . </s> <s>
# subst ppas
# w miejscowości UUUNKKK
# subst inf
# . . .
# qub adv
# zwrócił się do
# subst inf
# go jej UUUNKKK
# comp qub
# Jakie teraz może
# subst pcon
# wybierała . </s>
# subst adv
# . </s> <s>
# adj subst
# UUUNKKK na UUUNKKK
# ger subst
# <s> Na wejście
# fin subst
# końca lutego .
# subst adj
# . </s> <s>
# adj subst
# Każdy z uczniów
# subst ger
# Zdaniem wielu UUUNKKK
# adj adv
# Zakopanem , ul
# subst brev
# rację ? </s>
# adj num
# podpisów znane są
# praet impt
# maturalne : w
# adj praet
# <s> Jest jeszcze
# subst praet
# , długie szaty
# subst ger
# zwrot głowy w
# fin subst
# im ? </s>
# adv qub
# tej roboty nie
# subst ppas
# było by UUUNKKK
# adv qub
# tym , co
# subst adj
# UUUNKKK szczegółach :
# subst ger
# UUUNKKK panie -
# subst fin
# miasteczko znajdujące się
# adj subst
# sposób na UUUNKKK
# adj subst
# weszła do środka
# prep qub
# . </s> <s>
# subst ger
# czy nic im
# fin pcon
# więcej ale .
# fin praet
# UUUNKKK , więc
# fin qub
# oraz 9 domków
# subst ppas
# UUUNKKK tą władzę
# fin praet
# </s> <s> zaraz
# subst ger
# tego pracuje jakiś
# inf adv
# nie dba o
# prep fin
# , że UUUNKKK
# adj adv
# UUUNKKK on z
# adv subst
# proc . </s>
# fin pact
# , co to
# subst ppas
# <s> Na zdjęciach
# adj ppas
# UUUNKKK do UUUNKKK
# ger subst
# , pełno nie
# adj subst
# ani satysfakcji z
# subst adj
# formę " ,
# adj num
# jest postawa UUUNKKK
# subst ger
# z propozycją kumpel
# adj praet
# pracy administracji ,
# subst praet
# , bo kiedy
# praet inf
# Grześkowiak , posłów
# fin praet
# samochód . </s>
# adv qub
# . </s> <s>
# subst praet
# oczywiście </s> <s>
# fin pact
# UUUNKKK się do
# subst adj
# Ale nie chcieli
# subst adj
# UUUNKKK jak UUUNKKK
# conj pred
# <s> 2 -
# subst adj
# podchodzi , obejmuje
# subst xxx
# chcesz zabrać psa
# fin praet
# . </s> <s>
# subst adj
# że oni tam
# adv qub
# UUUNKKK em nim
# subst adj
# się na UUUNKKK
# ger subst
# razie polski UUUNKKK
# adj subst
# </s> <s> M
# subst conj
# . </s> <s>
# subst brev
# ? </s> <s>
# adj ppas
# przy tym samym
# subst adj
# tutaj jak na
# subst ger
# " Cóż Ty
# adj subst
# UUUNKKK się w
# adj subst
# </s> <s> To
# subst adv
# kran ? </s>
# adj subst
# wisiał na ścianie
# subst adj
# UUUNKKK i znaleźć
# fin subst
# przepisy prawne z
# subst ger
# Nikt rozsądny nie
# subst num
# złapie kilku UUUNKKK
# fin ppas
# UUUNKKK , drzewa
# subst ger
# UUUNKKK systemu UUUNKKK
# inf num
# , gdy fala
# subst adj
# </s> <s> Ale
# subst adv
# A , to
# fin praet
# kolejny już raz
# subst adj
# same słowa ,
# subst impt
# . </s> <s>
# subst adj
# w trzech sklepach
# subst adv
# UUUNKKK w UUUNKKK
# subst adj
# tutaj wieża wodna
# subst qub
# zgonu były UUUNKKK
# adj ger
# </s> <s> Jesteś
# subst adj
# UUUNKKK Chrystusa ,
# inf fin
# <s> - Szkoda
# fin impt
# <s> - Widzisz
# subst ppas
# </s> <s> Po
# subst adj
# UUUNKKK . </s>
# adj inf
# br . nieznani
# brev subst
# <s> Tyle ,
# fin inf
# że ci ,
# fin praet
# obecnie ze UUUNKKK
# subst adj
# <s> Człowiek był
# fin adj
# 55 , 17
# subst adj
# to nie niekoniecznie
# subst imps
# W umowie strony
# subst ger
# . która .
# subst adj
# UUUNKKK śmy zwłoki
# adj ppas
# rozwój techniki polskiej
# subst ppas
# podstawowe pojęcia UUUNKKK
# fin praet
# tyle postów do
# subst praet
# <s> – Jak
# fin pcon
# nie poradzi ,
# adj ppas
# mama rower .
# subst fin
# chrześcijańskich " do
# subst adj
# stulecia obowiązującym w
# subst fin
# sobie wmówić UUUNKKK
# fin ppas
# potrzeby . </s>
# fin inf
# – nie </s>
# adv subst
# . </s> <s>
# conj pred
# – ręce UUUNKKK
# subst adj
# Komisji Ustawodawczej o
# adj num
# w letniej UUUNKKK
# subst adj
# </s> <s> UUUNKKK
# subst ppas
# </s> <s> UUUNKKK
# adj praet
# gdy wchodziła już
# subst adj
# dyskusji publicznej </s>
# fin subst
# </s> <s> 3
# fin pcon
# - Ale gdyby
# subst adj
# . tej wielkiej
# fin praet
# spółki znaleźć można
# subst praet
# UUUNKKK z UUUNKKK
# fin praet
# <s> U Moniki
# praet fin
# a w 87
# subst adj
# nie otwarty .
# subst adj
# w dniach od
# subst adj
# śmy , że
# subst ppas
# </s> <s> UUUNKKK
# subst num
# UUUNKKK celem UUUNKKK
# adj subst
# , przyjazne i
# subst adj
# 31 zł .
# subst adj
# Do zadania pytania
# subst ppas
# UUUNKKK restauracja z
# subst ger
# <s> – do
# fin pcon
# się - UUUNKKK
# ppas inf
# do wykonania kolejnych
# subst fin
# nazwiska , jakby
# subst praet
# Na to brak
# adj subst
# pobytu oraz ważności
# subst adj
# dużo kłopotów zawodnikom
# pred subst
# zawsze . </s>
# subst adj
# pan przy nim
# subst adj
# UUUNKKK swojego życia
# subst fin
# po np .
# qub conj
# UUUNKKK problem .
# subst inf
# , które zapłaciła
# subst fin
# awansu zawodowego .
# subst adj
# . </s> <s>
# subst ger
# jak się UUUNKKK
# subst burk
# głęboko intymne i
# adj subst
# do zwycięstwa wiodła
# fin num
# " </s> <s>
# prep interj
# nagle jakby UUUNKKK
# subst ger
# się dzieje z
# subst adj
# " , ale
# subst adj
# że jest w
# qub comp
# tam zadzwonić no
# subst fin
# wewnętrznych . </s>
# subst fin
# dziedzinach życia publicznego
# subst adj
# . </s> <s>
# subst fin
# USA G .
# subst fin
# którym mowa w
# subst ppas
# powrotem niemal go
# ppas fin
# . </s> <s>
# subst ppas
# państwowych i samorządowych
# subst conj
# wartość rzeczy UUUNKKK
# fin ppas
# </s> <s> Są
# subst adj
# powiedzieć , że
# subst adj
# UUUNKKK " ,
# subst inf
# <s> To sygnał
# adj subst
# pod hasłem koń
# subst qub
# się więc z
# adj num
# zabronionego pod UUUNKKK
# subst adj
# <s> trzydzieści dwa
# subst praet
# UUUNKKK miał UUUNKKK
# subst adj
# Z 13 do
# subst praet
# by m wręcz
# prep subst
# każdym czasie ,
# qub conj
# 50 , poz
# fin praet
# Ksiądz Krzysztof (
# subst impt
# osoby , myślę
# fin subst
# pomocy medycznej ze
# conj adv
# <s> Ale potem
# fin ppas
# godziny później Ania
# subst fin
# , że UUUNKKK
# subst inf
# bazy wojskowej na
# adj ppas
# by m UUUNKKK
# subst ppron12
# skierowała wczoraj skargę
# adv conj
# UUUNKKK w UUUNKKK
# subst adj
# - mówi Andrzej
# subst qub
# wybrało aż 48
# subst adj
# , wziąć się
# ger ppas
# UUUNKKK , UUUNKKK
# fin qub
# UUUNKKK i nareszcie
# qub pred
# . Wojewódzki inspektor
# praet subst
# Przez kilka kolejnych
# adj praet
# </s> <s> Takie
# subst ppas
# . </s> <s>
# adv adj
# Pan Korwin -
# ger subst
# UUUNKKK w UUUNKKK
# subst ppas
# , w soboty
# adj praet
# - Tam ma
# subst pact
# polskie wycieczki do
# subst adj
# Jak pani UUUNKKK
# subst adj
# nawet wygra ,
# subst praet
# dla dobra przyrody
# subst pred
# </s> <s> 3
# subst adj
# UUUNKKK ( UW
# subst adj
# jaka to powinna
# subst praet
# nie stało .
# qub conj
# nie więcej mieli
# fin pcon
# ksiądz występuje na
# subst praet
# Stalin i Churchill
# praet adj
# weszły organizowane przez
# subst adj
# co robią .
# adj praet
# . </s> <s>
# subst adj
# UUUNKKK się ,
# subst adj
# nimi być wtedy
# subst num
# Z pięciu przeżyły
# subst ppas
# UUUNKKK śmy się
# fin inf
# Matejki jest zamknięta
# subst inf
# materiały i UUUNKKK
# subst impt
# miejscu , pracownicy
# adj ppas
# rachunku wynika ,
# subst adj
# <s> – nie
# qub conj
# tyle poważna ,
# praet inf
# ? </s> <s>
# adj ppas
# bo przecież ja
# subst qub
# jest bez świadczeń
# ger subst
# . rozdz .
# adj imps
# UUUNKKK na długo
# adj subst
# , czy UUUNKKK
# subst adj
# są na UUUNKKK
# adv num
# <s> Ostatnio do
# praet ppas
# ale . ale
# subst adj
# wspólna Europa mogła
# subst adj
# . </s> <s>
# subst praet
# UUUNKKK . </s>
# ger adj
# em go jako
# adv qub
# <s> mój UUUNKKK
# subst adj
# krok od zrobienia
# adv num
# się , chociaż
# fin praet
# piosenki . </s>
# subst ger
# UUUNKKK do spowiedzi
# subst ppas
# </s> <s> Może
# ppas adj
# by tej wiary
# subst adj
# <s> - Poseł
# subst ger
# życia . </s>
# adj ppas
# . </s> <s>
# adj subst
# do prokuratury ,
# fin praet
# i na zasadach
# fin subst
# UUUNKKK został UUUNKKK
# subst adj
# UUUNKKK - UUUNKKK
# inf imps
# " ( bo
# prep adj
# nowe idee .
# subst adj
# redukcja nauczycieli że
# subst adv
# </s> <s> –
# subst adj
# to dużo pracy
# subst adj
# UUUNKKK szlakiem Witkacego
# subst ger
# . </s> <s>
# subst adj
# <s> Jeśli nie
# subst adj
# Tutaj mamy jakąś
# subst ger
# UUUNKKK na lewo
# subst adj
# UUUNKKK się taka
# subst pred
# UUUNKKK 2006 (
# ger subst
# muszę . UUUNKKK
# subst ger
# gra z UUUNKKK
# adj praet
# </s> <s> UUUNKKK
# ger subst
# </s> <s> Nie
# num subst
# do 13 .
# adj ppas
# UUUNKKK się głosem
# subst fin
# funkcjonować " S
# adj ger
# możliwości ochrony życia
# ppron12 xxx
# – w tą
# subst adj
# terenie b .
# adj subst
# </s> <s> Ale
# ppas pact
# roku , już
# subst adj
# opowiedział o prawie
# fin pcon
# . </s> <s>
# praet imps
# </s> <s> –
# subst pact
# ale dlaczego ty
# ppas pact
# . </s> <s>
# adj inf
# lata raport zawierający
# subst xxx
# UUUNKKK , a
# subst fin
# </s> <s> Mieszkańcy
# subst adj
# UUUNKKK , który
# subst pact
# , żeby m
# subst adv
# w pierwszej połowie
# fin subst
# . a pani
# subst adj
# pewnością wpłynie bowiem
# subst pred
# zakończył się porażką
# fin praet
# na swoją kolej
# subst adj
# też tam nie
# ppas adj
# ) . </s>
# subst adv
# przez ministra .
# adv prep
# że studiował em
# subst adj
# zadać sobie to
# adj pact
# , nie miał
# subst adv
# , w których
# subst pact
# </s> <s> Nawet
# adj subst
# </s> <s> Rok
# subst adj
# . 1 ,
# adj subst
# w 1990 czy
# subst depr
# Tak jest –
# qub adv
# tego artykułu premier
# adj ppas
# braku pożywienia "
# subst adj
# przy drodze ,
# adj subst
# rodzin ofiar ,
# subst ppas
# UUUNKKK i UUUNKKK
# fin subst
# <s> W konkursie
# subst praet
# . </s> <s>
# subst fin
# UUUNKKK dla UUUNKKK
# adv subst
# wierzę w dalsze
# fin praet
# uwagę zasługuje grupa
# subst xxx
# </s> <s> Usłyszał
# subst conj
# że w ogóle
# subst adj
# dzieciom . </s>
# ppron12 adj
# <s> Wiem ,
# subst adj
# UUUNKKK - UUUNKKK
# subst impt
# . </s> <s>
# subst ger
# a ja nie
# fin inf
# <s> W :
# subst pred
# </s> <s> Ewa
# subst adj
# psychologów , a
# adj subst
# , i tyle
# adj ppas
# z Niemiec UUUNKKK
# subst prep
# wysoka temperatura i
# subst prep
# UUUNKKK , który
# fin pcon
# UUUNKKK wiele nowych
# adj num
# prawa miejscowego właściwy
# subst praet
# do ich użytku
# subst adj
# </s> <s> -
# adj subst
# było z tym
# inf interp
# i o handel
# adj ger
# wystawie można oglądać
# fin inf
# oraz art .
# subst fin
# </s> <s> W
# subst adj
# poniedziałek pięć prowincji
# subst adj
# UUUNKKK piosenkę o
# fin ger
# z tyłu </s>
# subst adj
# wstaje od stołu
# fin praet
# . </s> <s>
# adj subst
# mieszkań . </s>
# adj subst
# mojego wychowania .
# subst adj
# . jakby UUUNKKK
# num subst
# lecz mimo to
# fin praet
# 8 tys .
# subst adj
# Proszę państwa ,
# subst adj
# . </s> <s>
# fin subst
# od XIV w
# ppas adj
# <s> Nie wszyscy
# subst ppas
# UUUNKKK jest UUUNKKK
# subst ppas
# kolanach na małym
# adv conj
# </s> <s> Nie
# fin subst
# jedno kolano .
# fin praet
# Naszym kolegom wciąż
# subst adj
# UUUNKKK schodów szóstego
# subst ppron12
# , których UUUNKKK
# subst inf
# lekarzy , przyczyną
# subst ppas
# <s> Na polach
# adj num
# ten stary ,
# subst pact
# przez Zachód opozycji
# subst fin
# Zakładu dokumenty związane
# qub conj
# przyszłym roku .
# adj subst
# wodno - UUUNKKK
# subst ppas
# Walendziak zdecydował się
# subst adj
# . </s> <s>
# subst pcon
# em głos UUUNKKK
# subst adj
# , musi jeszcze
# subst adv
# <s> Pan zamku
# qub subst
# ich człowiek w
# fin pact
# 62 . </s>
# qub adv
# Był em na
# conj qub
# </s> <s> Po
# conj qub
# wymaga i analiz
# subst adj
# życia , do
# adj praet
# UUUNKKK , co
# subst fin
# się w pomocy
# subst ppas
# UUUNKKK . </s>
# qub conj
# jak się to
# adj subst
# UUUNKKK . </s>
# subst adj
# na to ,
# adj ppas
# " wątek jest
# prep subst
# morskie dla UUUNKKK
# subst adja
# </s> <s> Wszystko
# subst fin
# karny . </s>
# num adv
# UUUNKKK o UUUNKKK
# fin praet
# : w UUUNKKK
# adj subst
# niewielu . </s>
# fin imps
# nigdy się z
# fin pcon
# JEŚLI CZUJESZ ANTYPATIĘ
# subst fin
# . </s> <s>
# subst adj
# , jaką pełni
# adv prep
# . . .
# subst praet
# sędzia będzie miał
# subst num
# odpowiedział : Pytanie
# adj subst
# UUUNKKK usłyszał głosy
# adj ppas
# nieba jest wiodącym
# subst adj
# w którym pierwsza
# subst adj
# Pan Janek podał
# fin praet
# </s> <s> Jest
# subst ppas
# się on coraz
# subst adj
# - białą ,
# prep conj
# , nie UUUNKKK
# subst adj
# , która nie
# adj subst
# <s> Widocznie z
# subst inf
# <s> - Widział
# subst adj
# wody , a
# subst adj
# UUUNKKK materiału do
# subst adv
# żywy ze strachu
# subst adj
# UUUNKKK Mariana K
# qub fin
# , a nikt
# adj praet
# . </s> <s>
# subst ppas
# samo z tym
# adv conj
# <s> Był blady
# subst adj
# – Pani nadal
# adv num
# go . </s>
# ppas praet
# dogadać , ot
# subst ppas
# i Niemiec .
# subst fin
# <s> mnie odpada
# subst pact
# w myślach .
# subst praet
# w szczególności w
# fin pcon
# . </s> <s>
# praet subst
# tak mało miast
# fin ger
# pojawił się zapach
# subst adja
# śmy mu UUUNKKK
# adv adj
# tylko ja .
# fin subst
# <s> Nie była
# praet pcon
# kilka jest takich
# adj subst
# w tym 25
# subst adja
# nieba przez UUUNKKK
# ger subst
# <s> Nie wolno
# adj imps
# <s> Bo to
# subst pact
# UUUNKKK , UUUNKKK
# subst praet
# w tym roku
# subst adj
# nie wiem na
# fin adj
# k . UUUNKKK
# fin praet
# . </s> <s>
# ppas subst
# religijną odpowiedź tym
# adj subst
# zgłoszono wniosek o
# subst adj
# i czujesz potrzebę
# fin praet
# że ś nie
# subst adj
# w tym żadnej
# adv conj
# , ale od
# subst adv
# , gdy na
# subst adj
# <s> Zdecydowanie UUUNKKK
# subst pact
# prawo przypuszczać ,
# adj interj
# przykre stwierdzenie .
# fin adj
# Chciał by m
# subst ger
# herbaty i wina
# subst adj
# z koszyka jest
# subst adj
# prawdopodobnie było to
# subst ppas
# </s> <s> Nikogo
# conj qub
# <s> I ta
# subst adj
# stąd dotąd ,
# subst adj
# , bo proces
# subst ger
# i zawsze mojej
# subst fin
# tej pracy nie
# subst interj
# i w czasie
# subst adj
# . </s> <s>
# subst adj
# : „ o
# subst fin
# . . a
# subst pact
# dziś już dał
# prep interj
# . że jest
# subst praet
# ładu w Europie
# subst adj
# <s> Ona jednak
# prep brev
# a spośród UUUNKKK
# subst num
# nikt nic nie
# subst adj
# Może nie całkiem
# subst inf
# <s> Ale muszę
# ppas adj
# . </s> <s>
# adj subst
# </s> <s> -
# qub conj
# jego opinii ,
# subst pred
# UUUNKKK - podobne
# subst fin
# tam wiesz yyy
# subst ppas
# . Słowackiego do
# fin subst
# można się spodziewać
# num adv
# zamyka drogi .
# adj subst
# do mnie ,
# subst adj
# oddaje zapach ,
# ppas adjc
# i kieliszki .
# fin praet
# występują , po
# qub prep
# Mistrzostwa świata -
# subst imps
# NIE " potwierdziła
# subst adja
# , że to
# subst adj
# tak większość ,
# subst adj
# UUUNKKK , UUUNKKK
# adj subst
# 22 miliony ton
# prep qub
# czerwca ) zarząd
# subst ppas
# UUUNKKK . </s>
# fin imps
# zagraniczne toczy się
# subst adj
# na Pomorzu (
# adj subst
# </s> <s> Bo
# subst adj
# UUUNKKK [ ?
# adj ppas
# mamy problemy ,
# subst pact
# . </s> <s>
# adv qub
# na miejscu .
# adj subst
# i dystans do
# inf subst
# </s> <s> Czy
# subst adj
# Nie tylko wiedział
# subst adj
# UUUNKKK otrzymała od
# subst ger
# ? </s> <s>
# adj subst
# dwa portrety ,
# subst adj
# </s> <s> To
# ppas subst
# Do męża .
# fin praet
# osób . </s>
# subst adj
# polskiego mleka i
# praet adv
# o niskiej zawartości
# subst praet
# Napisał , ,
# subst adj
# dał em się
# adj subst
# UUUNKKK na UUUNKKK
# subst ppas
# <s> A :
# pact adj
# oraz termin ,
# adj ger
# na interpelację pana
# subst adj
# następnie w oknie
# subst fin
# , zakończenie wojen
# ger pact
# ) . </s>
# adv qub
# sama nie próbowała
# fin ger
# Naród od dawna
# subst fin
# Głosy : -
# adj ger
# UUUNKKK . </s>
# subst num
# nieznani jeszcze sprawcy
# praet subst
# którymi zdarza się
# subst fin
# . </s> <s>
# subst adj
# <s> To nie
# conj qub
# UUUNKKK , większą
# adv qub
# były fajne czasy
# subst num
# UUUNKKK ze ściany
# fin adv
# takich słów komentować
# subst pact
# ani jednego UUUNKKK
# fin inf
# mogły zadzwonić do
# num adv
# Nie wiem jak
# subst ppas
# Chodzi o UUUNKKK
# subst pred
# minister edukacji Andrzej
# subst ppas
# . </s> <s>
# subst adj
# nie znalazł się
# subst adj
# UUUNKKK również państwa
# adv qub
# nazwisko męża :
# subst adj
# UUUNKKK z domu
# ppas praet
# rokiem prezydenta UUUNKKK
# adj subst
# się i zaproponować
# adj ger
# poniżej 35 roku
# qub adv
# m fotel .
# qub adv
# UUUNKKK na podłogę
# subst fin
# niespokojny , UUUNKKK
# subst adj
# . </s> <s>
# subst adj
# dnia 20 października
# subst ger
# zaczynam się UUUNKKK
# subst ppas
# . </s> <s>
# subst adv
# Wam nie przeszkadzało
# praet ppas
# się powoli ,
# praet fin
# i pojawiają się
# praet ppas
# UUUNKKK została UUUNKKK
# subst ppas
# </s> <s> –
# subst inf
# I o tej
# subst adj
# roku . </s>
# subst praet
# forma własności ,
# subst adj
# Będą w nich
# subst adj
# mieli pytania do
# fin inf
# klientów , chętnych
# subst num
# ? </s> <s>
# praet imps
# każdy miesiąc .
# subst inf
# . </s> <s>
# subst ppas
# <s> W miastach
# conj qub
# oddziału lub UUUNKKK
# subst adj
# – no no
# adj pact
# badania kontrolne .
# subst fin
# wyrwało mi się
# subst inf
# , których UUUNKKK
# conj qub
# zabranie głosu pana
# subst adj
# by wówczas finansowe
# subst adj
# jest on UUUNKKK
# subst fin
# prowincji północnej przez
# fin praet
# • W weekendy
# subst adj
# coś bardziej UUUNKKK
# subst praet
# : do czego
# fin praet
# zamyka ją Stefan
# qub pred
# UUUNKKK , mówią
# praet pcon
# UUUNKKK ich nie
# subst ger
# poczuła , że
# subst adj
# UUUNKKK , UUUNKKK
# fin praet
# UUUNKKK . </s>
# subst adj
# mężczyźni w takich
# adj adv
# , była UUUNKKK
# subst qub
# UUUNKKK . </s>
# prep qub
# jakkolwiek starszy UUUNKKK
# adj subst
# <s> We Wrocławiu
# subst comp
# dziś . .
# adj num
# , napisz do
# adj pact
# UUUNKKK . </s>
# subst qub
# do wzrostu i
# subst adj
# g  cm
# subst pred
# tak . .
# conj qub
# , tym mniej
# subst praet
# się liści ,
# fin pcon
# . </s> <s>
# qub conj
# odpowiedział : "
# adj subst
# UUUNKKK : tzw
# adv prep
# UUUNKKK , że
# qub conj
# jeden z UUUNKKK
# fin pact
# UUUNKKK milczał przez
# inf subst
# mogła by m
# subst impt
# W sumie kilkadziesiąt
# fin inf
# lat siedemdziesiątych ,
# subst fin
# , na sile
# praet adv
# . </s> <s>
# subst pred
# ? </s> <s>
# conj pred
# UUUNKKK . UUUNKKK
# subst ger
# ? </s> <s>
# subst adj
# 18 . min
# fin praet
# którzy tworzyli zespół
# adj subst
# . 12 .
# subst adjp
# <s> Tymczasem firmy
# fin praet
# Czyli - UUUNKKK
# subst praet
# podniesienie ich do
# fin inf
# tego jest dużo
# subst adj
# , by przestał
# subst adj
# UUUNKKK się z
# subst adj
# . . </s>
# qub adv
# rzuca w górę
# subst ppas
# UUUNKKK . UUUNKKK
# adj subst
# O wpół do
# subst impt
# „ im mniej
# praet fin
# jednak przed próbą
# qub adv
# grzechy zamachu UUUNKKK
# subst praet
# takie są okna
# adj num
# UUUNKKK , UUUNKKK
# subst ppas
# pisarki – na
# subst adv
# Ty jutro UUUNKKK
# adv qub
# miejsca i powtórnie
# fin praet
# dzika , bo
# fin subst
# bywają tacy co
# inf subst
# w kościele św
# conj brev
# z ciałem mamy
# fin imps
# UUUNKKK mnie potwory
# fin praet
# żadna dyskusja na
# subst adj
# wojnę . </s>
# ppas adj
# tej samej sprawie
# subst adv
# Czy będzie to
# adj fin
# w drzwiach kancelarii
# adj praet
# , wśród nich
# pred subst
# UUUNKKK , zanim
# adj subst
# <s> – a
# subst adj
# środowiska ekonomicznego firmy
# inf adj
# <s> Chcę też
# subst inf
# UUUNKKK . </s>
# subst adj
# , że w
# subst praet
# był em wtedy
# subst praet
# sztuk powstał on
# fin adj
# UUUNKKK metrów od
# subst impt
# końca , którego
# subst adj
# nie ma większego
# subst adj
# i Krystian UUUNKKK
# fin impt
# poprzedzającym rok UUUNKKK
# subst ger
# . </s> <s>
# fin praet
# funkcjonuje Liceum i
# subst adj
# tak no tak
# subst fin
# UUUNKKK , to
# inf subst
# debaty . </s>
# qub prep
# środowisku które jest
# subst fin
# ale tylko w
# fin subst
# UUUNKKK podaje datę
# qub comp
# Lepiej na wszelki
# brev subst
# stycznia 1999 r
# subst adj
# , na których
# adj subst
# UUUNKKK się w
# adj ger
# </s> <s> (
# subst ppas
# innym razem UUUNKKK
# adj praet
# bohatera ( UUUNKKK
# subst adj
# z krótkiej historii
# adj subst
# oni poszli </s>
# subst praet
# , natomiast liczbę
# subst ppas
# UUUNKKK " sowiecki
# subst pact
# Tylko Siostry UUUNKKK
# fin ger
# UUUNKKK w centrum
# subst
# xxx
# UUUNKKK m się
# subst fin
# o jak UUUNKKK
# conj qub
# UUUNKKK powinno być
# subst ger
# niż u UUUNKKK
# subst adj
# przypadkach policjanci twierdzą
# subst adj
# udziałów w UUUNKKK
# adj subst
# , będzie miał
# subst adj
# </s> <s> Monika
# subst adj
# UUUNKKK do sypialni
# subst interj
# Zjednoczonych większość ludzi
# subst ppas
# . </s> <s>
# comp qub
# mu 31 zł
# subst adj
# <s> Nie jest
# subst adj
# ile tygodni ?
# inf praet
# coś zrobić ,
# subst num
# 8 % osób
# subst praet
# UUUNKKK " Gazety
# subst ppas
# . </s> <s>
# adv qub
# roboty , UUUNKKK
# fin adj
# UUUNKKK warunków nauczania
# subst imps
# </s> <s> Halina
# fin impt
# </s> <s> UUUNKKK
# subst ppas
# 1994 . </s>
# adj num
# </s> <s> "
# qub conj
# 1999 r .
# subst adj
# ci pomogę ,
# num adj
# – prywatne osoby
# subst pact
# UUUNKKK , a
# conj pred
# ) . </s>
# fin adj
# ? </s> <s>
# ppron3 brev
# Był em jedynym
# adj ppas
# dokonać zakupów poza
# adj ppas
# jedną z UUUNKKK
# subst praet
# zawodowym . </s>
# qub adv
# całego seksualnego zamieszania
# num adj
# z uwzględnieniem przepisów
# fin inf
# </s> <s> UUUNKKK
# subst qub
# imprezie zorganizowanej na
# subst ppas
# w pewnym momencie
# qub adv
# swoje ulubione UUUNKKK
# praet imps
# co ten ?
# subst inf
# mi jednak z
# subst adj
# drzwiczki do tego
# conj adv
# stylu zachodnim .
# adj subst
# Artur nigdy nie
# subst praet
# jest za pomocą
# praet adj
# UUUNKKK , np
# qub subst
# UUUNKKK skierowała do
# qub comp
# </s> <s> UUUNKKK
# subst num
# </s> <s> i
# fin praet
# wynikało , że
# adj fin
# i tego i
# fin praet
# naszego regionu nie
# subst adj
# </s> <s> UUUNKKK
# subst adv
# UUUNKKK walizkę ,
# subst brev
# w ewolucji Świata
# brev subst
# - kręci głową
# pred subst
# . </s> <s>
# subst adj
# UUUNKKK się burza
# fin adj
# Mężczyzna ani nie
# conj subst
# zasady moralne ,
# subst adj
# Komentarz do wyniku
# subst prep
# UUUNKKK i UUUNKKK
# subst fin
# żona Maria i
# subst ppas
# Zawsze powtarzam sobie
# adj praet
# 20 maja w
# inf adv
# 3 ) UUUNKKK
# adj fin
# tysięcy złotych rocznie
# subst adj
# 1939 , na
# adj subst
# jest potrzebne .
# subst praet
# ( z wyjątkiem
# pred subst
# szczęście w postaci
# subst fin
# . </s> <s>
# subst pact
# znać . </s>
# subst adj
# . </s> <s>
# conj qub
# polskie . </s>
# subst pact
# UUUNKKK i V
# subst adja
# otoczenie . </s>
# adj pact
# jest dalej UUUNKKK
# subst adj
# prognozy naszego UUUNKKK
# qub prep
# UUUNKKK , często
# conj qub
# przy ulicy UUUNKKK
# adv prep
# listę uczestników naszej
# adj subst
# , a w
# prep qub
# <s> – czyli
# adj subst
# wzrok daleko przed
# adj ppas
# UUUNKKK jest dla
# subst adv
# . mięso UUUNKKK
# adj fin
# UUUNKKK nie sposób
# ppas adj
# <s> Pan Bóg
# qub adv
# ? </s> <s>
# subst ppas
# w piątek .
# fin impt
# . </s> <s>
# subst adj
# zwykle przewodniczył komisji
# ppas adj
# UUUNKKK był ostatni
# subst pred
# UUUNKKK do UUUNKKK
# subst adj
# <s> Takim właśnie
# subst fin
# starości , choć
# subst fin
# </s> <s> Wieczorem
# subst qub
# auto nie do
# adj ppas
# </s> <s> Według
# subst adj
# przekazywał mu część
# brev subst
# poznaje pan ?
# subst ppas
# UUUNKKK . </s>
# prep conj
# " , z
# subst ppas
# </s> <s> Szczerze
# subst adv
# Polski . </s>
# adj subst
# z 15 UUUNKKK
# adj pact
# y Kaśka że
# subst ppas
# było . </s>
# praet fin
# międzynarodowe wystawy oraz
# adj pact
# Ministrów określi ,
# subst adj
# tys . pracowników
# subst fin
# który obejść można
# subst num
# usiedli przy stole
# fin praet
# było nacisnąć w
# adv num
# się go uratować
# subst ger
# sala była aż
# subst adj
# UUUNKKK roku okazało
# subst adj
# , że lepiej
# ppas pcon
# <s> Tym bardziej
# subst adj
# </s> <s> UUUNKKK
# adj subst
# <s> - No
# pred qub
# dobrze , bo
# pact praet
# pewnych złych obyczajów
# fin inf
# bała się UUUNKKK
# adv qub
# na rok wyraźny
# adj adja
# <s> Ma umożliwić
# subst inf
# wyboru , prosimy
# subst impt
# </s> <s> –
# subst praet
# trzeciego lub jego
# subst praet
# fakt , że
# subst ger
# i stąd całe
# fin ppas
# </s> <s> To
# adj subst
# UUUNKKK , UUUNKKK
# adj subst
# " Prawdy "
# adj subst
# także nauczyciele .
# subst comp
# ktoś inaczej uważa
# subst brev
# Wiesław N .
# praet fin
# dla rolników .
# fin praet
# . </s> <s>
# adv qub
# odpowiedzialności , konsekwencji
# adv qub
# - rzucił UUUNKKK
# subst praet
# <s> - UUUNKKK
# ppron12 adj
# . zł )
# adj ppas
# ciągu następnych lat
# fin adj
# panu nie podoba
# adj praet
# Danii by to
# adj subst
# mogli , mówi
# subst praet
# . y pana
# subst ppas
# </s> <s> Jest
# subst adv
# już nie UUUNKKK
# adj ger
# Myślę , że
# subst adj
# nie ma żadnego
# subst qub
# UUUNKKK kursy akcji
# subst ger
# : Tak ,
# subst adj
# , której nie
# adj adv
# pracowników . </s>
# subst ger
# . </s> <s>
# praet adv
# listopadzie poniżej 9
# inf ppas
# którzy powiedzieli ,
# subst num
# , a potem
# subst fin
# ciebie wpływu ;
# fin praet
# trzech partiach ,
# subst adv
# strony żadnego UUUNKKK
# subst fin
# się ostatecznie w
# subst adj
# UUUNKKK . </s>
# subst adj
# dziękuję </s> <s>
# subst fin
# też tyle ludzi
# subst pact
# . </s> <s>
# praet inf
# wszystkim ochrony sfer
# conj qub
# by , aby
# subst brev
# UUUNKKK te potwory
# subst ger
# : " Przez
# adj subst
# UUUNKKK coś UUUNKKK
# subst ppas
# , podając jako
# subst adj
# UUUNKKK nie powinny
# adj subst
# większością głosów .
# subst burk
# </s> <s> Najlepszym
# subst adj
# . </s> <s>
# subst num
# bardzo to nie
# inf praet
# <s> Ostatnio jednak
# subst ger
# tą wolą jest
# subst adj
# , oraz składek
# subst praet
# Żyda – było
# ger adj
# maja </s> <s>
# subst brev
# jego przyjęcie zwykłej
# subst adv
# </s> <s> UUUNKKK
# subst adj
# w tym roku
# subst fin
# dopiero będzie UUUNKKK
# subst praet
# się trzymać stałej
# subst adj
# kampanię wyborczą .
# subst adj
# – u nas
# adj ppas
# . </s> <s>
# subst adj
# się wydaje .
# subst adv
# tak że kiedy
# fin praet
# . </s> <s>
# fin praet
# stało , UUUNKKK
# subst praet
# kolegium może być
# subst adv
# Urzędu Statystycznego do
# subst praet
# kolei w obozie
# adj subst
# UUUNKKK ? </s>
# subst ppas
# określonych w art
# conj qub
# wschodniego . </s>
# adj praet
# wiem </s> <s>
# subst adj
# uczynić z szefów
# fin impt
# . </s> <s>
# subst adv
# Izba Pracy .
# adj subst
# </s> <s> UUUNKKK
# subst adj
# Chinach " UUUNKKK
# adj subst
# Obie największe UUUNKKK
# adj subst
# . 2 pkt
# subst adj
# aha </s> <s>
# subst praet
# , nawet jeśli
# ppas pact
# jednostkach . </s>
# qub conj
# kościoła . </s>
# subst praet
# nie występuje jako
# fin pcon
# </s> <s> Nagłe
# adj subst
# wokół znali ich
# qub conj
# ) , UUUNKKK
# adj num
# </s> <s> UUUNKKK
# conj prep
# ! </s> <s>
# adj subst
# można by UUUNKKK
# ppas praet
# 10 . UUUNKKK
# adj pact
# jez . UUUNKKK
# subst praet
# delegatów przechodzą w
# conj prep
# i któryś z
# fin adj
# UUUNKKK , profesor
# fin praet
# <s> – ale
# fin praet
# Mimo to ,
# prep subst
# wieczorem należy się
# praet fin
# UUUNKKK . </s>
# qub pred
# . </s> <s>
# aglt brev
# </s> <s> -
# subst adj
# em o każdym
# fin ppas
# Ukrainie i UUUNKKK
# subst praet
# dziwne wrażenie jakby
# subst adj
# sądzi pan ?
# subst comp
# bielizny i nie
# subst adv
# , w którym
# ger subst
# odejdzie , UUUNKKK
# praet pcon
# im już przecież
# praet subst
# z oferowanych jej
# subst praet
# w skład innego
# fin pcon
# by mu UUUNKKK
# subst adv
# . </s> <s>
# adj ppas
# którzy byli UUUNKKK
# subst ger
# bał się pan
# subst adv
# . </s> <s>
# conj prep
# tym kartki ze
# subst adj
# Zespołu Szkół UUUNKKK
# praet subst
# dobrze . </s>
# praet subst
# UUUNKKK " ,
# subst xxx
# niedzielę , 13
# subst praet
# . </s> <s>
# praet inf
# <s> - Ja
# subst adj
# sny w kolorach
# conj qub
# składał m.in .
# subst pact
# UUUNKKK z UUUNKKK
# adj subst
# - Kto chce
# adj ger
# <s> Na razie
# adj subst
# UUUNKKK kiedyś .
# ger ppas
# UUUNKKK laboratorium w
# adj fin
# , zwyciężyli .
# praet comp
# uznano , że
# adj subst
# rolnictwa . </s>
# conj qub
# rejonie walki ,
# praet fin
# . </s> <s>
# subst ppas
# jang ) jest
# adj adja
# na stanowiskach służbowych
# qub adv
# osobę do UUUNKKK
# subst adj
# padały na UUUNKKK
# subst ger
# UUUNKKK muzyków ,
# subst adj
# UUUNKKK śmieci ,
# fin pact
# <s> Bez przesady
# subst adj
# związku z powyższym
# subst ppas
# z policją ,
# subst adj
# w moim przypadku
# fin subst
# udział w wielu
# subst ppas
# . </s> <s>
# subst ppas
# . </s> <s>
# subst adj
# . </s> <s>
# fin praet
# UUUNKKK . </s>
# praet ppas
# , wstrzymało się
# subst ppas
# <s> Możliwe UUUNKKK
# adj num
# tak ? </s>
# subst praet
# dziś własnym wysiłkiem
# subst adv
# ) lub UUUNKKK
# adj subst
# na cele mieszkaniowe
# adj subst
# UUUNKKK dzieci na
# adj subst
# <s> W gruncie
# subst adj
# UUUNKKK polskich UUUNKKK
# subst impt
# bankowego ( druki
# subst adj
# ; na twarzy
# qub conj
# będziesz miała super
# subst adj
# i Ireneusz UUUNKKK
# fin pcon
# musi mu przypominać
# adj subst
# , choć je
# adj subst
# nim . </s>
# subst brev
# syna . </s>
# fin subst
# , potem UUUNKKK
# adj ppas
# – no to
# adj fin
# UUUNKKK « powszechnie
# fin praet
# dorosłe kobiety .
# subst ger
# Brytanii , Irlandii
# praet adj
# o których mowa
# subst ppas
# , z domu
# subst adja
# pomocy są UUUNKKK
# subst adj
# przy piecu .
# subst adj
# UUUNKKK jednorazowo 12
# subst adj
# pana życie musi
# fin praet
# . </s> <s>
# ppas inf
# </s> <s> Dokument
# subst pact
# królewskiego w Lublinie
# conj qub
# kilka kotów ,
# fin subst
# to godzina UUUNKKK
# fin ppas
# <s> Dlaczego Agencja
# ger numcol
# </s> <s> Lecz
# praet pcon
# UUUNKKK się nisko
# subst praet
# nami mówiąc -
# subst adj
# 8 : 2
# subst xxx
# . </s> <s>
# adv num
# ubiegłym o UUUNKKK
# adv conj
# . . nie
# subst inf
# który podpisał UUUNKKK
# conj prep
# miasto . </s>
# adj imps
# UUUNKKK pracy jako
# subst praet
# potrzebuje nasze dziecko
# praet adv
# inaczej poseł Czarnecki
# adj pact
# <s> - Kiedy
# subst adj
# UUUNKKK dzieli od
# subst adj
# Wysoką Izbę ,
# adj subst
# wysokie płace minimalne
# fin praet
# odległość przy pomocy
# fin adv
# radą . </s>
# adv qub
# UUUNKKK ) .
# subst praet
# <s> Trzeba żyć
# subst impt
# pozostałych zaś przypadkach
# conj qub
# . </s> <s>
# subst praet
# obrazu składu UUUNKKK
# subst pact
# UUUNKKK duszę UUUNKKK
# adj num
# </s> <s> Dziś
# subst adj
# Zapraszam na
# subst adj
# , i że
# subst pred
# <s> Mam UUUNKKK
# conj adv
# , było sześciu
# adj adv
# nasi ! </s>
# subst adj
# się do życia
# subst adj
# em czas odwiedzić
# subst pred
# . . .
# fin impt
# woda ! "
# subst fin
# <s> Wiem ,
# subst adj
# Stalin zaszedł ,
# subst fin
# UUUNKKK biją na
# adj subst
# śmierci dzieci -
# ppas subst
# tylko te Doroty
# subst adj
# UUUNKKK kamerami i
# ppron12 adj
# </s> <s> –
# subst fin
# UUUNKKK nastolatków .
# subst interj
# UUUNKKK to w
# subst interj
# przedsiębiorstwa . </s>
# subst ger
# nie dotyczy jakiegoś
# subst adj
# <s> A co
# subst adj
# , ale i
# subst xxx
# się , jak
# adj subst
# </s> <s> Jednym
# subst adj
# rejony wyborcze ustala
# ppas praet
# zaangażowania odbiorcy .
# subst adj
# nie było ,
# subst adj
# UUUNKKK , UUUNKKK
# adj subst
# UUUNKKK z dziećmi
# subst fin
# </s> <s> Jeżeli
# ger num
# tu patrzę UUUNKKK
# adj subst
# UUUNKKK . </s>
# subst pact
# UUUNKKK . </s>
# fin praet
# wie wie UUUNKKK
# subst adj
# . </s> <s>
# subst praet
# pan , wygląda
# subst interj
# . </s> <s>
# subst adj
# UUUNKKK , przeżyła
# adj subst
# UUUNKKK i UUUNKKK
# subst praet
# Co ja mówię
# conj qub
# " i UUUNKKK
# subst ger
# UUUNKKK ( UUUNKKK
# subst pcon
# że ktoś UUUNKKK
# subst adj
# Przed pięćdziesięciu laty
# adj subst
# dostał za użycie
# ppron12 adj
# no jasne jakim
# subst ger
# <s> – nie
# fin subst
# UUUNKKK we francuskim
# pact adj
# UUUNKKK danie ,
# ppron12 adj
# niego wiersz ,
# subst ppas
# z rodziców ;
# subst brev
# nocnych trwały w
# subst adj
# <s> We wszystkich
# conj qub
# przestępstwa do Prokuratury
# subst adj
# pracy . </s>
# fin ppas
# swych dwóch metrów
# adj fin
# Jeszcze w UUUNKKK
# subst pact
# napastnicy , zwłaszcza
# adj subst
# oświadczenie o przyjęciu
# subst pcon
# UUUNKKK się i
# subst qub
# związkowych składek .
# adj subst
# mogli najpierw UUUNKKK
# fin ppas
# UUUNKKK . </s>
# subst adj
# około 35 minut
# fin praet
# UUUNKKK . </s>
# adj pact
# UUUNKKK czasami sąsiada
# subst adj
# czytał taka UUUNKKK
# prep brev
# Musimy uzupełnić zapasy
# subst adj
# <s> Gdy mamy
# fin praet
# się o UUUNKKK
# subst adj
# UUUNKKK ma UUUNKKK
# ger subst
# też wniosek o
# adj subst
# trafiło dziecko ,
# subst inf
# . </s> <s>
# conj qub
# <s> Nie znam
# conj qub
# wychodząc z trybu
# subst qub
# trafi do szpitala
# adj ppas
# <s> Jeśli UUUNKKK
# adj subst
# taka próba żeby
# subst adj
# cm , UUUNKKK
# subst xxx
# Boga , skutecznie
# fin impt
# </s> <s> Czy
# adj fin
# , mieli spore
# subst inf
# UUUNKKK listy przedsiębiorstw
# adv qub
# dziecko potrafi tak
# ger subst
# dla orkiestry .
# subst praet
# , to na
# subst adj
# , czy tym
# adj num
# samo była znana
# subst ger
# o takich UUUNKKK
# fin adv
# UUUNKKK młodych przedsiębiorców
# subst ger
# . </s> <s>
# conj qub
# UUUNKKK , próbował
# fin pcon
# ośrodek pomocy osobom
# fin adj
# starają się ,
# praet fin
# musi sprzedawać swoje
# adj subst
# Rosja prowadzi wojnę
# praet subst
# UUUNKKK , UUUNKKK
# subst fin
# . Mickiewicza 5
# subst praet
# bardzo ważne -
# subst adja
# UUUNKKK materiał UUUNKKK
# subst adv
# Czemu nie ?
# prep xxx
# a u pasa
# subst ger
# W Sejmie odbyło
# adv conj
# UUUNKKK , UUUNKKK
# qub adv
# nazwiska kandydata z
# subst prep
# </s> <s> Jeżeli
# prep qub
# , podobnie jak
# subst pact
# UUUNKKK terminy ,
# adj subst
# myślisz i się
# subst qub
# . </s> <s>
# adv num
# kwiatek . </s>
# subst fin
# no na razie
# adj subst
# tę sprawę ,
# praet qub
# </s> <s> UUUNKKK
# subst adj
# UUUNKKK za nią
# subst adj
# oczu może doprowadzić
# subst adj
# dziesiątej udało mi
# conj qub
# <s> W salonie
# subst ppas
# drugą przyjął .
# conj qub
# tych spraw -
# num adv
# , co UUUNKKK
# subst adj
# na telefon .
# subst adj
# . </s> <s>
# subst qub
# UUUNKKK and UUUNKKK
# subst praet
# <s> – Muszę
# fin impt
# UUUNKKK - informuje
# adj ppas
# niewielu - tłumaczy
# subst adj
# Mam działkę wielkości
# ger imps
# ochrony jezior "
# prep adv
# . </s> <s>
# fin praet
# powodzeniem , gdyż
# subst qub
# nasze wyniki ekonomiczne
# adj pact
# z dzieciństwa UUUNKKK
# subst adv
# szefem zespołu prokuratorów
# ppas adj
# Stalowa Wola .
# subst num
# której większość pragnęła
# ppron3 brev
# </s> <s> UUUNKKK
# adj subst
# świecie , poza
# subst adj
# ( czyli praktycznie
# adj fin
# do końca ich
# subst adj
# gdzie jest UUUNKKK
# subst ppas
# się także do
# adj subst
# . </s> <s>
# subst inf
# , jak język
# adj subst
# ale gdyby UUUNKKK
# praet fin
# by mogła sama
# subst praet
# <s> nie ma
# subst xxx
# UUUNKKK się do
# adj subst
# ? </s> <s>
# ger pact
# Wielkiego , autorstwa
# subst inf
# </s> <s> Najwięcej
# brev subst
# UUUNKKK matki .
# subst fin
# obie ) UUUNKKK
# adj subst
# odbiera się UUUNKKK
# subst adj
# </s> <s> MON
# fin praet
# UUUNKKK , UUUNKKK
# fin adj
# </s> <s> Dzięki
# ger subst
# " nr 7
# subst impt
# się zacznie .
# fin ppas
# opowiedział się za
# pact adv
# Nie ma opłat
# adj pact
# UUUNKKK w wojnę
# subst adj
# ) , to
# subst praet
# wykaz gmin i
# fin ger
# po chwili .
# subst praet
# są dwukrotnie gorsze
# adv prep
# ani nawet ramieniem
# subst ger
# UUUNKKK zza UUUNKKK
# fin praet
# w środku miasta
# subst adj
# ty , Shirley
# subst qub
# się bowiem ,
# adj subst
# . </s> <s>
# subst fin
# </s> <s> UUUNKKK
# subst praet
# UUUNKKK i inne
# adj ppas
# UUUNKKK poprawił własny
# subst fin
# <s> Jak ujawnił
# subst adj
# UUUNKKK ! </s>
# qub conj
# UUUNKKK , UUUNKKK
# subst praet
# działających w czasie
# subst fin
# UUUNKKK ? -
# subst adj
# prezentów miało dojść
# subst adj
# UUUNKKK . </s>
# subst xxx
# UUUNKKK walki z
# adj subst
# . </s> <s>
# fin praet
# UUUNKKK twórczość kolejnych
# fin subst
# To te UUUNKKK
# subst ger
# pracowników firmy .
# subst adj
# UUUNKKK , działacza
# adj adv
# Rzym nie zdążył
# subst fin
# po odejściu na
# fin impt
# UUUNKKK ( woj
# subst adj
# </s> <s> Nie
# subst praet
# o braku etyki
# adj num
# Mam prawo nie
# conj qub
# czasu wyjaśnienia sprawy
# subst praet
# zginąć bez sensu
# praet subst
# strategię wobec banku
# adj num
# Banku Ludowego ,
# subst adj
# : ( UUUNKKK
# subst adj
# . </s> <s>
# inf adv
# To wszystko wcale
# fin subst
# miejscu . </s>
# fin praet
# nich nie UUUNKKK
# adj pact
# , do prezentacji
# fin inf
# <s> Ustawa ta
# adj subst
# do Rosji .
# subst adv
# UUUNKKK </s> <s>
# adv qub
# </s> <s> Te
# subst praet
# no . .
# fin praet
# </s> <s> Rejestr
# subst adj
# biednych z UUUNKKK
# adj praet
# UUUNKKK : -
# subst adja
# z okazji urodzin
# adj ger
# wiesz </s> <s>
# fin subst
# oświadczył w niedzielę
# subst ger
# , że złamał
# subst adv
# mniej mieszkańców metropolii
# adv qub
# UUUNKKK , że
# ppas subst
# powiedzieć że to
# adj adv
# tak definitywnie .
# subst fin
# . </s> <s>
# subst ppas
# . </s> <s>
# adj pact
# film " UUUNKKK
# subst fin
# odłożył słuchawkę .
# subst adj
# </s> <s> –
# adj subst
# wolność i demokrację
# fin subst
# masz jakiejś UUUNKKK
# fin praet
# , zniszczony w
# subst ger
# UUUNKKK . </s>
# adj praet
# musiał wypełnić i
# inf subst
# . </s> <s>
# subst impt
# Dziękuję bardzo panu
# fin praet
# <s> Jest mój
# subst qub
# wygrać po 100
# subst praet
# <s> – no
# subst adj
# groźny , czy
# subst adv
# </s> <s> UUUNKKK
# adj adv
# UUUNKKK ją utrzymać
# subst adj
# Dopiero teraz UUUNKKK
# subst adj
# Niemców , UUUNKKK
# adj subst
# ...
# praet fin
# szybkość decyzji ,
# adj subst
# UUUNKKK „ UUUNKKK
# subst praet
# – niech będzie
# subst praet
# było wymieniać i
# subst adj
# do wejścia taka
# subst adj
# w tej zmianie
# subst adj
# UUUNKKK napad na
# subst adj
# bibliotekę , ale
# subst ppas
# i przeżył .
# fin subst
# UUUNKKK cieszą się
# adj ger
# 3 : P
# subst adj
# UUUNKKK , że
# subst brev
# niej użytkowanie obiektu
# fin ppron3
# . </s> <s>
# subst fin
# z Instytutu rejestr
# pred conj
# krzesło elektryczne "
# subst pred
# . </s> <s>
# subst ger
# grunt pod nogami
# subst adj
# wygląd </s> <s>
# subst adj
# to </s> <s>
# adj ppas
# <s> Dla lekarzy
# subst adja
# 12 lat pozbawienia
# subst adj
# o zwykłym UUUNKKK
# subst xxx
# . </s> <s>
# subst pcon
# się do UUUNKKK
# adj ger
# <s> Niemcy UUUNKKK
# ppron12 burk
# całości . </s>
# conj qub
# talentem . </s>
# adj subst
# od razu wielkiej
# adj subst
# by tym większy
# subst adj
# . . .
# subst ppas
# UUUNKKK oraz Andrzej
# fin subst
# . </s> <s>
# fin adj
# </s> <s> W
# subst ppas
# </s> <s> Mogą
# subst pact
# UUUNKKK czy taka
# subst praet
# się kilka dni
# subst praet
# pamięci kościoła w
# fin ppas
# . </s> <s>
# subst adv
# </s> <s> Woda
# fin ppas
# skazany może zrozumieć
# subst qub
# mi się podobała
# subst inf
# <s> Nie było
# subst impt
# UUUNKKK przez UUUNKKK
# prep brev
# UUUNKKK w sferze
# subst prep
# , rzecznik prasowy
# fin praet
# to doprowadzić do
# qub ppron3
# troska o dzieci
# adj subst
# wojskowej , a
# subst adj
# </s> <s> Krystyna
# subst adj
# ładna , UUUNKKK
# subst prep
# , autor UUUNKKK
# adv prep
# : - Wiele
# conj adj
# </s> <s> ja
# subst brev
# informacją , że
# subst adj
# </s> <s> –
# qub adv
# we własnym zakresie
# brev subst
# tylko </s> <s>
# adj ppas
# w Goleniowie zajmie
# subst adj
# UUUNKKK się UUUNKKK
# subst praet
# latem na najwyższą
# subst adj
# stawianie siebie wyżej
# subst adv
# </s> <s> Gdy
# subst praet
# jutro . </s>
# adj subst
# bez życia osobistego
# ger subst
# Tu wszyscy są
# fin subst
# a to dąży
# adj subst
# przez masło .
# adj ger
# <s> I w
# subst adj
# mi " dzień
# fin inf
# cię spotka ;
# fin praet
# w sferze kontaktów
# subst ger
# wyobraźni ) ,
# subst num
# np . UUUNKKK
# subst fin
# prawo trzymać UUUNKKK
# subst praet
# uciekł . .
# subst ger
# – gdy biegnie
# adj praet
# w tamtejszej prasie
# subst adj
# Nasze poparcie dla
# comp qub
# ale też parą
# subst ppas
# chyba zaczął em
# subst adj
# A . W
# adj ger
# UUUNKKK , znajomi
# subst adj
# zakładu górniczego .
# praet adv
# ludność polska codziennie
# adj qub
# wydajności , dopóty
# ger subst
# UUUNKKK , jednak
# adj adv
# Państwa PRL ,
# subst pact
# wcale nie chcę
# qub fin
# UUUNKKK wydać taką
# subst ppas
# się tekstu w
# adj adv
# do Włoch albo
# adj subst
# swobodę . </s>
# subst conj
# powinien być przy
# ppas subst
# </s> <s> Pojęcie
# subst ger
# <s> Szukał em
# subst adj
# - Dwóch dorosłych
# subst xxx
# lecz niewielkich rozmiarów
# subst adj
# że takie fajne
# subst inf
# UUUNKKK Izbę Kontroli
# subst adj
# <s> Według badań
# interp subst
# <s> Teraz nie
# subst num
# pracy może dostać
# subst pred
# x 1 .
# subst ppas
# , którego UUUNKKK
# num adv
# </s> <s> przecież
# praet ppas
# <s> Generał UUUNKKK
# subst qub
# . </s> <s>
# adj ppas
# Czy musiały śmy
# qub subst
# </s> <s> -
# adv prep
# wyborach konkurentów .
# subst pred
# względu na dodatkowe
# adj adv
# </s> <s> –
# subst adj
# . </s> <s>
# subst ppas
# </s> <s> UUUNKKK
# adj adv
# się zadowolić UUUNKKK
# fin praet
# naciskiem na muszą
# subst xxx
# warto poświęcić trochę
# subst adj
# roku w sierpniu
# subst fin
# A potem były
# adj subst
# UUUNKKK drogowy .
# subst pred
# UUUNKKK raport będzie
# adv qub
# wiele sygnałów ze
# subst adj
# a ich energia
# adj subst
# UUUNKKK " ,
# adj pact
# <s> - UUUNKKK
# fin subst
# która zajmowała się
# fin inf
# UUUNKKK 2000 E
# inf ger
# UUUNKKK , UUUNKKK
# subst adj
# UUUNKKK . </s>
# fin impt
# budownictwa przemysłowego UUUNKKK
# subst brev
# Polski ( UUUNKKK
# subst inf
# dla czytelnika czytelnika
# subst fin
# kolegom . </s>
# conj prep
# UUUNKKK cztery okazy
# adj adv
# się znaleźć pracę
# subst adj
# dziewięć lat .
# subst comp
# Tacy byli śmy
# subst adj
# i odjechali .
# subst num
# sportową i UUUNKKK
# subst ppas
# Marcina . </s>
# fin inf
# król włoski .
# adj pact
# dym . czyli
# subst ger
# i same nerwy
# subst praet
# , że wcale
# ppas praet
# </s> <s> Adam
# ger adj
# było ściśle z
# subst adj
# jest zagrożeniem dla
# subst adj
# UUUNKKK , gdyby
# subst adv
# o braku uprawnienia
# subst ppas
# W wypadku wygaśnięcia
# subst fin
# . </s> <s>
# subst praet
# prawda , a
# praet fin
# Trzeba będzie dobrać
# ger adj
# . </s> <s>
# subst pcon
# </s> <s> UUUNKKK
# fin subst
# w którym prowadził
# qub adv
# rozpocząć </s> <s>
# subst pcon
# zatrzymać lidera "
# subst fin
# łączności - UUUNKKK
# adj imps
# <s> 10 .
# praet ppas
# UUUNKKK , a
# ppas adj
# po części UUUNKKK
# adj subst
# znajdujących się w
# subst ger
# , bo żyją
# subst pred
# jeżeli działalność w
# adj subst
# w pracach specjalistycznych
# subst ppas
# dodaje . </s>
# adj subst
# , rozpocznie się
# subst adj
# </s> <s> –
# subst adj
# zbiorniki paliwa ,
# adj subst
# , bo ta
# qub adv
# , gdzie będzie
# ger num
# . </s> <s>
# pred conj
# racji zdecydował się
# subst inf
# UUUNKKK . </s>
# subst pred
# </s> <s> We
# adv num
# - Panie UUUNKKK
# subst pact
# UUUNKKK się na
# adj subst
# powietrzu . </s>
# fin subst
# przypominam sobie moje
# subst praet
# drzwi . </s>
# ppas imps
# czyli tym ,
# adj ppas
# głupio . </s>
# subst xxx
# rząd ustąpił UUUNKKK
# prep adv
# Widmar całą drogę
# adv subst
# pewne problemy </s>
# fin praet
# <s> Właśnie temu
# subst adj
# przyjęcia utworu ,
# adj subst
# UUUNKKK od niszczenia
# adj ppas
# <s> - Na
# subst xxx
# Spotkali śmy się
# adj subst
# Ja nie mam
# subst ger
# temu chcąc przekonać
# fin praet
# w dziewczynę za
# subst ger
# coś od dołu
# ger subst
# UUUNKKK przede wszystkim
# subst pred
# samo co UUUNKKK
# subst inf
# UUUNKKK , UUUNKKK
# fin pcon
# Jest to UUUNKKK
# adj ppas
# zgłosiło się do
# subst qub
# Brukseli niż bałagan
# fin adj
# zwłaszcza mięsa .
# subst ger
# UUUNKKK . .
# subst praet
# <s> taki program
# subst ppas
# . 2 pkt
# subst adv
# coś tam )
# adj num
# Chociaż muszę przyznać
# subst ppas
# a więc każdego
# subst pact
# w północnej części
# subst adj
# <s> Kierowcy ,
# subst ppas
# firmy . </s>
# prep qub
# UUUNKKK emerytury jednorazowo
# subst adj
# UUUNKKK i jej
# fin praet
# . </s> <s>
# adj pact
# , co należy
# fin praet
# mil morskich ,
# fin praet
# Będę myślał o
# subst ger
# </s> <s> UUUNKKK
# subst fin
# </s> <s> Wszystko
# fin impt
# UUUNKKK , który
# ger subst
# jest rada UUUNKKK
# adj num
# zabójstwo dwóch UUUNKKK
# subst ppas
# </s> <s> UUUNKKK
# fin inf
# nie należy do
# subst adj
# UUUNKKK w przeszłości
# subst adj
# człowiek ginie ,
# subst ger
# milionów ludzi na
# adj subst
# . </s> <s>
# subst adj
# Żaden plon się
# qub adv
# M . E
# subst adj
# ministerstwo , co
# conj qub
# <s> Ale o
# praet fin
# mimo że ich
# subst praet
# ponad pierwszych tysiąc
# fin praet
# i za każdym
# adj num
# 20 grudnia 2000
# fin subst
# to samo .
# adv num
# </s> <s> Twój
# subst conj
# wiem jak jak
# subst interj
# z wysokością o
# ger adj
# ławie w Petersburgu
# adj subst
# zadawał em pytania
# subst ger
# Obok okien .
# adv num
# UUUNKKK - 250
# adj ppas
# poddał by się
# num subst
# : uprawnienia wydane
# adj praet
# 11 . UUUNKKK
# ppron12 xxx
# na szczęście UUUNKKK
# subst adj
# Ale sposobu na
# adj subst
# . </s> <s>
# ger ppas
# Obecnie tworzą się
# subst adv
# z trudem jakieś
# subst adv
# </s> <s> Czasem
# subst adv
# co naprawdę jest
# subst pred
# , dąży do
# inf subst
# w Poznaniu organizuje
# subst ger
# mowa w art
# subst adj
# Może po UUUNKKK
# subst ger
# brzmiało " UUUNKKK
# subst num
# </s> <s> UUUNKKK
# subst ppas
# , ma być
# pred subst
# nr 55 )
# subst inf
# ostrego starcia między
# subst adj
# gminy . </s>
# subst adj
# <s> - Nie
# adj ppron12
# UUUNKKK od dłuższego
# qub comp
# czy wtedy jeszcze
# subst adj
# zewnątrz . </s>
# subst pcon
# , że mój
# inf adv
# kości i wysłał
# fin qub
# UUUNKKK się z
# subst adj
# jest zainteresować ,
# prep adv
# pamiętać . </s>
# praet pcon
# i uprawnień .
# adv qub
# , o co
# subst adj
# w ogródku UUUNKKK
# adv num
# diet ( średnio
# fin praet
# kolejce . </s>
# subst prep
# pomników przyrody .
# adj subst
# ma trudności ze
# subst adj
# przeciwny temu UUUNKKK
# qub comp
# W moim odczuciu
# adj subst
# A dał UUUNKKK
# subst adj
# nie jest UUUNKKK
# subst fin
# <s> Grzegorz P
# adj subst
# w Stanach Zjednoczonych
# subst num
# to tak zwane
# adj pact
# wiesz . .
# adj subst
# <s> " UUUNKKK
# adj subst
# tylko kolejnym UUUNKKK
# fin inf
# Świata , UUUNKKK
# fin inf
# </s> <s> Byli
# adj ppas
# <s> To samo
# subst ger
# się nagle ,
# prep brev
# UUUNKKK - grupa
# subst adj
# <s> - Proszę
# pred subst
# </s> <s> UUUNKKK
# fin subst
# . </s> <s>
# subst adj
# nas i na
# adj fin
# " kultury fizycznej
# subst imps
# . </s> <s>
# subst ppas
# 1975 . </s>
# subst inf
# wszystko będzie ładnie
# ger subst
# złożył w Sądzie
# subst adj
# czwartek w szkole
# fin subst
# jest się UUUNKKK
# fin impt
# , wyciąga długą
# qub ppron3
# </s> <s> Na
# adj subst
# </s> <s> UUUNKKK
# praet impt
# konferencja , na
# fin praet
# spędzić czas w
# praet subst
# Marii Curie UUUNKKK
# subst adj
# bez uzgodnienia z
# adv num
# nawet wytłumaczyć ,
# subst adj
# wczoraj umowę o
# fin praet
# 1 , wydaje
# subst adj
# UUUNKKK . </s>
# fin adj
# tej jakże UUUNKKK
# num adv
# którym się bawił
# subst praet
# : wydatki na
# subst fin
# R . C
# subst adj
# jak i inne
# subst fin
# . </s> <s>
# subst pact
# . . </s>
# subst ger
# , że UUUNKKK
# subst ppas
# wnioskodawcy proponują w
# subst adj
# z polskich surowców
# pact ger
# jego nominacji na
# conj pred
# zapłacić ludziom ,
# fin praet
# UUUNKKK , że
# subst adj
# UUUNKKK . </s>
# subst adj
# Lekarze ze szpitala
# subst ger
# dokument został zatwierdzony
# fin praet
# ust . 6
# ger adj
# " . </s>
# adj fin
# UUUNKKK nazywają UUUNKKK
# prep qub
# do głosowania .
# adj subst
# UUUNKKK . </s>
# subst ger
# : 4 .
# fin praet
# co się UUUNKKK
# ppas subst
# wypowiedzieć umowę .
# ger subst
# bo dziś już
# fin praet
# UUUNKKK , autor
# adj subst
# na szczęście .
# adj ger
# one teoretycznie pod
# subst fin
# <s> Także on
# conj adv
# komunistycznej flagi Rosja
# subst adv
# </s> <s> –
# subst adv
# straty . </s>
# subst praet
# . </s> <s>
# subst comp
# tym nie martwi
# subst adj
# obyczajów , a
# subst ppas
# UUUNKKK czynnikiem ,
# subst praet
# roku 1952 jako
# qub adv
# Sorry , ale
# aglt brev
# UUUNKKK ? </s>
# subst adj
# ? </s> <s>
# subst adj
# robi </s> <s>
# subst adj
# </s> <s> Dzięki
# subst qub
# Życie jest szare
# subst praet
# dobre stosunki między
# subst praet
# </s> <s> Pieniądze
# subst praet
# i pośpiechu .
# subst ger
# Nowa sztuka UUUNKKK
# subst praet
# . </s> <s>
# praet pact
# <s> - UUUNKKK
# adv qub
# </s> <s> UUUNKKK
# adj fin
# , jeszcze nie
# subst adj
# </s> <s> Prof
# conj qub
# do pokoju .
# subst adj
# się na całą
# adj subst
# UUUNKKK żadnych wartości
# subst fin
# em go UUUNKKK
# subst praet
# UUUNKKK publiczność UUUNKKK
# adv conj
# w sferze dźwięków
# subst prep
# </s> <s> -
# subst ppas
# reguły z II
# ppas inf
# pisarzy . z
# comp qub
# jeżeli nie zostaną
# fin pact
# był na wojnie
# subst fin
# miejskich . </s>
# prep interj
# dyskusji . </s>
# subst pact
# UUUNKKK sobie z
# adj subst
# </s> <s> tam
# subst adj
# zespół gospodarzy ,
# adj subst
# o czym w
# subst adv
# </s> <s> Na
# conj qub
# – obraz </s>
# fin subst
# , wylądował samolot
# subst adj
# dobre wyniki ,
# adj praet
# <s> Pan UUUNKKK
# fin ppas
# sugestie , bo
# subst ger
# </s> <s> Z
# ppas adj
# jako siedzenia przy
# praet subst
# serce . </s>
# subst adj
# bogactwo życia ,
# conj qub
# , że będziemy
# conj adj
# " lub "
# subst ppas
# Port Artur padł
# adj num
# . </s> <s>
# ger pact
# ustalono , iż
# subst pact
# </s> <s> -
# fin imps
# będzie w w
# fin praet
# opowiada o UUUNKKK
# subst praet
# UUUNKKK młodszy ,
# subst adj
# , młodszy brat
# subst adj
# , jeśli są
# subst ger
# jakby od początku
# subst ppas
# UUUNKKK śmy UUUNKKK
# subst ppas
# w tym sposób
# subst pred
# UUUNKKK . </s>
# subst fin
# UUUNKKK głównie o
# subst num
# . </s> <s>
# subst praet
# kolacji do kuchni
# subst adj
# . był tym
# subst ppas
# piłką w UUUNKKK
# subst conj
# rzeczywistością i UUUNKKK
# subst adj
# UUUNKKK . </s>
# subst pact
# prezydent miał by
# prep conj
# <s> Wiersze o
# comp qub
# 12 proc .
# adj subst
# zegarek . </s>
# qub adv
# tyłu </s> <s>
# subst adj
# UUUNKKK po UUUNKKK
# subst ppas
# słuchają ich kierowcy
# subst adj
# . </s> <s>
# inf fin
# obiecał , że
# adj subst
# pocz . XX
# subst pred
# że Kowalski UUUNKKK
# qub interj
# . </s> <s>
# conj prep
# . </s> <s>
# fin ppas
# i Niemcy –
# subst praet
# karę za UUUNKKK
# adj pred
# wokół budżetu ,
# subst adj
# na temat dialogu
# subst adj
# , że nogi
# subst num
# – rzucił em
# subst adj
# która w 36
# adj pact
# UUUNKKK dokumentację .
# subst adj
# <s> I nie
# adj fin
# <s> Teraz UUUNKKK
# subst adj
# </s> <s> Te
# subst adj
# kierowców , UUUNKKK
# subst ppas
# też własną kulturę
# subst adj
# <s> Wydawało mu
# subst adj
# oraz procedur medycznych
# subst fin
# współpracy politycznej z
# ppas subst
# <s> – proszę
# adj subst
# . : Puzon
# qub adv
# . min spotkania
# adv subst
# <s> Znowu poprawiła
# fin praet
# – Jak to
# subst adj
# <s> Komendant wyglądał
# fin subst
# Wprawdzie ja nie
# adv qub
# , w UUUNKKK
# fin subst
# jest swego rodzaju
# qub adv
# wielkiego sukcesu artystycznego
# subst adj
# UUUNKKK właściwie nie
# ger subst
# tego stracić .
# subst fin
# UUUNKKK się własnym
# praet subst
# <s> Rząd winien
# subst adv
# 14  91
# subst adj
# UUUNKKK uderzył w
# adj fin
# UUUNKKK środek ma
# praet fin
# swą nazwę od
# fin praet
# temat w tekście
# fin praet
# znaczeniu . </s>
# subst ger
# . dojdzie do
# subst ppas
# em go .
# subst adj
# związanej ze UUUNKKK
# fin adj
# . </s> <s>
# conj qub
# UUUNKKK . </s>
# subst fin
# powiedział : -
# ger adj
# UUUNKKK chodzi na
# prep interj
# UUUNKKK , dają
# subst ppas
# go nie znał
# subst impt
# jest działaniem wewnętrznym
# adj imps
# celu utrzymania UUUNKKK
# subst adj
# Od dawna nie
# fin inf
# , żeby nie
# subst fin
# </s> <s> –
# subst adj
# UUUNKKK - 2,5
# subst qub
# z wojennym UUUNKKK
# qub conj
# r . i
# subst adj
# nowym systemie ,
# subst pcon
# </s> <s> Dziękuję
# conj qub
# dany miesiąc ,
# subst adj
# " to ciocia
# subst pred
# znaczy się Łódź
# ppron12 xxx
# stycznia . </s>
# inf pcon
# Poznania . </s>
# subst ppas
# wbrew pozorom inflacja
# subst pact
# bo ty też
# subst fin
# UUUNKKK , pełne
# fin inf
# mówi mieszkanka UUUNKKK
# adj num
# . </s> <s>
# conj qub
# córka , UUUNKKK
# subst adj
# dojdzie na UUUNKKK
# adj ppas
# UUUNKKK deszczu ,
# adj num
# tak długo był
# subst impt
# Radni podkreślają brak
# subst ppas
# wstrzymał od głosu
# subst adv
# . </s> <s>
# subst adj
# ma zaś UUUNKKK
# fin subst
# angielsku . </s>
# adj ppas
# w niczym nie
# subst num
# </s> <s> W
# subst adj
# - Czy pan
# adj num
# a poziom UUUNKKK
# subst qub
# nową propozycję .
# subst adj
# tego ogromna ,
# subst adj
# odkryła na temat
# subst adja
# , co zaszło
# adj subst
# - Ja m
# fin impt
# UUUNKKK , za
# subst adv
# przeciw " UUUNKKK
# subst adj
# <s> Jest to
# adj subst
# tam nie było
# subst adj
# UUUNKKK Marek S
# adj subst
# UUUNKKK mają powiązania
# adj praet
# , której dokumentów
# subst adj
# </s> <s> UUUNKKK
# subst interj
# już od 4
# adj praet
# nie miał em
# conj qub
# Natomiast według UUUNKKK
# fin praet
# w klasie ,
# subst ger
# UUUNKKK polska firma
# adj subst
# UUUNKKK , lecz
# fin subst
# <s> - To
# fin pact
# pierwszy . </s>
# ppas adj
# UUUNKKK mieszkaniowych .
# subst adj
# </s> <s> UUUNKKK
# ger adj
# bieżących relacjach (
# subst adj
# UUUNKKK , z
# qub adv
# czwartku droga ma
# adj subst
# , jaki cel
# subst adj
# UUUNKKK mu UUUNKKK
# subst ppas
# własnej osoby .
# adj subst
# żeby m ja
# ppas adj
# pod tym względem
# ppas subst
# komisariatu kolejowego policji
# ppron12 subst
# szukam , ich
# ppas pact
# <s> Ja mam
# prep brev
# czyżby prawda aż
# fin pcon
# <s> Po UUUNKKK
# qub conj
# miejscem spotkań gejów
# subst fin
# </s> <s> Było
# subst fin
# dla wszystkich pracowników
# adj subst
# mogą być UUUNKKK
# subst ger
# zadał mu jeszcze
# qub conj
# . </s> <s>
# subst fin
# działalności ministra UUUNKKK
# subst adj
# telewizyjne , będące
# subst ppas
# , która ma
# fin subst
# … – zaczęła
# ppas ger
# sobie sprawy z
# prep qub
# UUUNKKK dostęp do
# subst inf
# UUUNKKK . </s>
# pred subst
# Że istnieją jej
# subst adj
# </s> <s> Ostatnie
# praet fin
# Was powinien em
# adv num
# robić i jak
# ger subst
# . </s> <s>
# adj subst
# w którym UUUNKKK
# subst ppas
# to jest może
# subst adj
# Marcinkiewicza i UUUNKKK
# qub adv
# UUUNKKK , co
# subst adj
# UUUNKKK o szybę
# adj praet
# </s> <s> nie
# subst ppas
# wypadkach drogowych oraz
# adj pact
# pracowników więzienia ,
# subst adj
# UUUNKKK i Londynie
# adj ppas
# kogo </s> <s>
# subst adj
# . </s> <s>
# subst conj
# UUUNKKK się do
# subst adj
# . </s> <s>
# adj subst
# 16 proc .
# adj praet
# i nie było
# subst ppas
# . przyjęła sprawozdanie
# subst ppas
# bo się okaże
# subst adj
# produkuje się UUUNKKK
# ger subst
# UUUNKKK . </s>
# subst ger
# będzie innych klientów
# adj subst
# musi wymyślić coś
# qub comp
# ktoś spoza jedzie
# subst ppas
# . </s> <s>
# subst fin
# Anglicy , Francuzi
# subst adj
# do 15 tysięcy
# subst adj
# , a jest
# subst num
# , przewodniczył tow
# subst adj
# mnie za wariata
# subst pact
# myślą , że
# subst ger
# W pierwszej kolejności
# adj ger
# zaledwie około 50
# adj interj
# </s> <s> Dzięki
# subst adj
# UUUNKKK jej kształt
# subst ger
# Zaczęło się to
# subst conj
# już od nas
# ppas praet
# ludzi którzy właśnie
# subst adj
# górskich i rzekach
# subst ger
# </s> <s> Dziękuję
# subst adj
# UUUNKKK umieszczony na
# conj adv
# UUUNKKK , to
# subst praet
# UUUNKKK - Hitlera
# ppas subst
# nie jest nazbyt
# subst fin
# ja widział em
# prep subst
# </s> <s> jak
# qub comp
# jeszcze stan "
# adv conj
# <s> Równocześnie z
# fin praet
# w miejscach znacznych
# ppas fin
#
# 14.49% of mistagged words were marked as unknown to the model (i.e. occurred fewer than 5 times in the corpus). The other mistagged words are displayed above.
